# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial']

# %%
budget_season = pd.read_csv('Fig. 1 radical budget by season.csv')

# %%
JJA = budget_season[budget_season['Time']=="JJA"]
DJF = budget_season[budget_season['Time']=="DJF"]

# %% [markdown]
# ### O(${^1}$D) radical budget

# %%
f = plt.figure(num=None, figsize=(2, 10), dpi=100, facecolor='w', edgecolor='k')

S = budget_season['Time']
prod1 = budget_season['P1']*10**(-6)
loss1 = -budget_season['P2']*10**(-6)
loss2 = -budget_season['P3']*10**(-6)
loss3 = -budget_season['P4']*10**(-6)

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='salmon', edgecolor='black')
plt.bar(S, loss1, width=a, color='mistyrose', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color='white', bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='silver', bottom=loss1+loss2, edgecolor='black')
plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)

plt.yticks(fontsize=16)
plt.xticks(fontsize=16, rotation=90)

ax=plt.gca()
#ax.spines['top'].set_linewidth(0)
#ax.spines['right'].set_linewidth(0)

#f.savefig("Fig. 1a decomposition of O(1D) budget.pdf", bbox_inches="tight")

# %%
o3prod_colors = ['darkslategrey','palegoldenrod','turquoise']
o3loss_colors = ['midnightblue','gold','silver','steelblue']

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

data = JJA

S = data['Time']
prod1 = data['P1']*10**(-6)
loss1 = -data['P2']*10**(-6)
loss2 = -data['P3']*10**(-6)
loss3 = -data['P4']*10**(-6)

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, loss1, width=a, color='whitesmoke', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='mediumturquoise', bottom=loss1+loss2, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4a decomposition of O(1D) budget JJA.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

data = DJF

S = data['Time']
prod1 = data['P1']*10**(-6)
loss1 = -data['P2']*10**(-6)
loss2 = -data['P3']*10**(-6)
loss3 = -data['P4']*10**(-6)

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, loss1, width=a, color='whitesmoke', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='mediumturquoise', bottom=loss1+loss2, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4e decomposition of O(1D) budget DJF.pdf", bbox_inches="tight")

# %% [markdown]
# ### OH radical budget

# %%
f = plt.figure(num=None, figsize=(2, 10), dpi=100, facecolor='w', edgecolor='k')

S = budget_season['Time']

prod1 = budget_season['P6']*10**(-6)
prod2 = budget_season['P5']*10**(-6)
prod3 = budget_season['P7']*10**(-6)

loss1 = -budget_season['P8']*10**(-6)
loss2 = -budget_season['P9']*10**(-6)
loss3 = -budget_season['P10']*10**(-6)
loss4 = -budget_season['P11']*10**(-6)
loss5 = -budget_season['P12']*10**(-6)
loss6 = -budget_season['P13']*10**(-6)

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='salmon', edgecolor='black')
plt.bar(S, prod2, width=a, color='lemonchiffon', bottom=prod1, edgecolor='black')
plt.bar(S, prod3, width=a, color='paleturquoise', bottom=prod1+prod2, edgecolor='black')

plt.bar(S, loss1, width=a, color='mistyrose', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color='white', bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='silver', bottom=loss1+loss2, edgecolor='black')
plt.bar(S, loss4, width=a, color='mistyrose', bottom=loss1+loss2+loss3, edgecolor='black')
plt.bar(S, loss5, width=a, color='white', bottom=loss1+loss2+loss3+loss4, edgecolor='black')
plt.bar(S, loss6, width=a, color='silver', bottom=loss1+loss2+loss3+loss4+loss5, edgecolor='black')
plt.ylabel("OH chemical budget compositions by season", fontsize=16)

plt.yticks(fontsize=16)
plt.xticks(fontsize=16, rotation=90)

ax=plt.gca()
#ax.spines['top'].set_linewidth(0)
#ax.spines['right'].set_linewidth(0)

#f.savefig("Fig. 1b decomposition of OH budget.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

data = JJA

S = data['Time']
prod1 = data['P6']*10**(-6)
prod2 = data['P5']*10**(-6)
prod3 = data['P7']*10**(-6)

loss1 = -data['P8']*10**(-6)
loss2 = -data['P9']*10**(-6)
loss3 = -data['P10']*10**(-6)
loss4 = -data['P11']*10**(-6)
loss5 = -data['P12']*10**(-6)
loss6 = -data['P13']*10**(-6)
loss456 = loss4 + loss5 + loss6

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, prod2, width=a, color='aliceblue', bottom=prod1, edgecolor='black')
plt.bar(S, prod3, width=a, color='gainsboro', bottom=prod1+prod2, edgecolor='black')
plt.bar(S, loss1, width=a, color='whitesmoke', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='mediumturquoise', bottom=loss1+loss2, edgecolor='black')
plt.bar(S, loss456, width=a, color='azure', bottom=loss1+loss2+loss3, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4b decomposition of OH budget JJA.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

data = DJF

S = data['Time']
prod1 = data['P6']*10**(-6)
prod2 = data['P5']*10**(-6)
prod3 = data['P7']*10**(-6)

loss1 = -data['P8']*10**(-6)
loss2 = -data['P9']*10**(-6)
loss3 = -data['P10']*10**(-6)
loss4 = -data['P11']*10**(-6)
loss5 = -data['P12']*10**(-6)
loss6 = -data['P13']*10**(-6)
loss456 = loss4 + loss5 + loss6

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, prod2, width=a, color='aliceblue', bottom=prod1, edgecolor='black')
plt.bar(S, prod3, width=a, color='gainsboro', bottom=prod1+prod2, edgecolor='black')
plt.bar(S, loss1, width=a, color='whitesmoke', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='mediumturquoise', bottom=loss1+loss2, edgecolor='black')
plt.bar(S, loss456, width=a, color='azure', bottom=loss1+loss2+loss3, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4f decomposition of OH budget DJF.pdf", bbox_inches="tight")

# %% [markdown]
# ### HO${_2}$ radical budget

# %%
f = plt.figure(num=None, figsize=(2, 10), dpi=100, facecolor='w', edgecolor='k')

S = budget_season['Time']

prod1 = budget_season['P14']*10**(-6)
prod2 = budget_season['P15']*10**(-6)
prod3 = budget_season['P16']*10**(-6)
prod4 = budget_season['P17']*10**(-6)

loss1 = -budget_season['P18']*10**(-6)
loss2 = -budget_season['P19']*10**(-6)
loss3 = -budget_season['P20']*10**(-6)
loss4 = -budget_season['P21']*10**(-6)
loss5 = -budget_season['P22']*10**(-6)

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='salmon', edgecolor='black')
plt.bar(S, prod2, width=a, color='lemonchiffon', bottom=prod1, edgecolor='black')
plt.bar(S, prod3, width=a, color='paleturquoise', bottom=prod1+prod2, edgecolor='black')
plt.bar(S, prod4, width=a, color='paleturquoise', bottom=prod1+prod2+prod3, edgecolor='black')

plt.bar(S, loss1, width=a, color='mistyrose', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color='white', bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='silver', bottom=loss1+loss2, edgecolor='black')
plt.bar(S, loss4, width=a, color='mistyrose', bottom=loss1+loss2+loss3, edgecolor='black')
plt.bar(S, loss5, width=a, color='white', bottom=loss1+loss2+loss3+loss4, edgecolor='black')
plt.ylabel("HO${_2}$ chemical budget compositions by season", fontsize=16)

plt.yticks(fontsize=16)
plt.xticks(fontsize=16, rotation=90)

ax=plt.gca()
#ax.spines['top'].set_linewidth(0)
#ax.spines['right'].set_linewidth(0)

#f.savefig("Fig. 1c decomposition of HO2 budget.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

Data = JJA

S = data['Time']
prod1 = data['P14']*10**(-6)
prod2 = data['P15']*10**(-6)
prod3 = data['P16']*10**(-6)
prod4 = data['P17']*10**(-6)
prod34 = prod3 + prod4

loss1 = -data['P18']*10**(-6)
loss2 = -data['P19']*10**(-6)
loss3 = -data['P20']*10**(-6)
loss4 = -data['P21']*10**(-6)
loss5 = -data['P22']*10**(-6)
loss2345 = loss2 + loss3 + loss4 + loss5

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, prod2, width=a, color='aliceblue', bottom=prod1, edgecolor='black')
plt.bar(S, prod34, width=a, color='gainsboro', bottom=prod1+prod2, edgecolor='black')
plt.bar(S, loss1, width=a, color='mediumturquoise', bottom=0, edgecolor='black')
plt.bar(S, loss2345, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4c decomposition of HO2 budget JJA.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

Data = DJF

S = data['Time']
prod1 = data['P14']*10**(-6)
prod2 = data['P15']*10**(-6)
prod3 = data['P16']*10**(-6)
prod4 = data['P17']*10**(-6)
prod34 = prod3 + prod4

loss1 = -data['P18']*10**(-6)
loss2 = -data['P19']*10**(-6)
loss3 = -data['P20']*10**(-6)
loss4 = -data['P21']*10**(-6)
loss5 = -data['P22']*10**(-6)
loss2345 = loss2 + loss3 + loss4 + loss5

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, prod2, width=a, color='aliceblue', bottom=prod1, edgecolor='black')
plt.bar(S, prod34, width=a, color='gainsboro', bottom=prod1+prod2, edgecolor='black')
plt.bar(S, loss1, width=a, color='mediumturquoise', bottom=0, edgecolor='black')
plt.bar(S, loss2345, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4g decomposition of HO2 budget DJF.pdf", bbox_inches="tight")

# %% [markdown]
# ### CH${_3}$O${_2}$ radical budget

# %%
f = plt.figure(num=None, figsize=(2, 10), dpi=100, facecolor='w', edgecolor='k')

S = budget_season['Time']

prod1 = budget_season['P23']*10**(-6)
prod2 = budget_season['P24']*10**(-6)

loss1 = -budget_season['P25']*10**(-6)
loss2 = -budget_season['P26']*10**(-6)
loss3 = -budget_season['P27']*10**(-6)

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='salmon', edgecolor='black')
plt.bar(S, prod2, width=a, color='lemonchiffon', bottom=prod1, edgecolor='black')

plt.bar(S, loss1, width=a, color='mistyrose', bottom=0, edgecolor='black')
plt.bar(S, loss2, width=a, color='white', bottom=loss1, edgecolor='black')
plt.bar(S, loss3, width=a, color='silver', bottom=loss1+loss2, edgecolor='black')
plt.ylabel("CH${_3}$O${_2}$ chemical budget compositions by season", fontsize=16)

plt.yticks(fontsize=16)
plt.xticks(fontsize=16, rotation=90)

ax=plt.gca()
#ax.spines['top'].set_linewidth(0)
#ax.spines['right'].set_linewidth(0)

#f.savefig("Fig. 1d decomposition of CH3O2 budget.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

data = JJA

S = data['Time']
prod1 = data['P23']*10**(-6)
prod2 = data['P24']*10**(-6)

loss1 = -data['P25']*10**(-6)
loss2 = -data['P26']*10**(-6)
loss3 = -data['P27']*10**(-6)
loss23 = loss2 + loss3

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, prod2, width=a, color='aliceblue', bottom=prod1, edgecolor='black')
plt.bar(S, loss1, width=a, color='mediumturquoise', bottom=0, edgecolor='black')
plt.bar(S, loss23, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4d decomposition of CH3O2 budget JJA.pdf", bbox_inches="tight")

# %%
f = plt.figure(num=None, figsize=(0.5, 10), dpi=100, facecolor='w', edgecolor='k')

data = DJF

S = data['Time']
prod1 = data['P23']*10**(-6)
prod2 = data['P24']*10**(-6)

loss1 = -data['P25']*10**(-6)
loss2 = -data['P26']*10**(-6)
loss3 = -data['P27']*10**(-6)
loss23 = loss2 + loss3

a = 0.75

plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
plt.bar(S, prod1, width=a, color='midnightblue', edgecolor='black')
plt.bar(S, prod2, width=a, color='aliceblue', bottom=prod1, edgecolor='black')
plt.bar(S, loss1, width=a, color='mediumturquoise', bottom=0, edgecolor='black')
plt.bar(S, loss23, width=a, color="cornsilk", bottom=loss1, edgecolor='black')
#plt.ylabel("O(${^1}$D) chemical budget compositions by season", fontsize=16)
#plt.xlabel(" ", fontsize=0)

ax=plt.gca()
#ax.yaxis.tick_right()
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_locator(plt.NullLocator())
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.spines['left'].set_linewidth(0)
ax.spines['bottom'].set_linewidth(0)

plt.yticks(fontsize=0)
plt.xticks(fontsize=0, rotation=90)

f.savefig("Extended Data Fig. 4h decomposition of CH3O2 budget DJF.pdf", bbox_inches="tight")
