# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial']

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %%
data = pd.read_csv('/Users/csuen/Desktop/Sun-NG-24/radicals/representative regions/UKESM1-0-LL_2010_2014_representative_regions(ver240113).csv')

# %% [markdown]
# #### Calculate dynamic regression

# %%
d_ho2_oh_beta = data.groupby('region').apply(lambda g: sm.OLS(g['ho2_mole'], g[['oh_mole']]).fit().params)
d_ho2_oh_ste = data.groupby('region').apply(lambda g: sm.OLS(g['ho2_mole'], g[['oh_mole']]).fit().HC0_se)

o3_mean = data.groupby('region').mean()['o3']
o3_std = data.groupby('region').std()['o3']
o3_ct = data.groupby('region').count()['o3']
o3_ste = o3_std/np.sqrt(o3_ct/5)

# %%
HOx = pd.DataFrame()
HOx['beta'] = d_ho2_oh_beta
HOx['beta_ste'] = d_ho2_oh_ste
HOx['o3_ppb'] = o3_mean*10**9
HOx['HOx'] = HOx['beta']/HOx['o3_ppb']
HOx['HOx_ste'] = HOx['beta_ste']/HOx['o3_ppb']
# Out:
#              beta  beta_ste     o3_ppb       HOx   HOx_ste
# region
# AUS      8.514530  0.504224  21.908209  0.388646  0.023015
# BRA     47.563649  1.550559  21.903138  2.171545  0.070792
# BTH      0.258473  0.011399  21.578030  0.011979  0.000528
# CA       2.129049  0.124942  32.774687  0.064960  0.003812
# CCE      1.972342  0.111034  33.468971  0.058930  0.003318
# COD     27.340055  2.023979  29.898853  0.914418  0.067694
# DEU      2.514762  0.071490  24.981628  0.100664  0.002862
# FIN     14.640855  0.710823  22.499470  0.650720  0.031593
# FRA      5.472910  0.114697  29.816768  0.183551  0.003847
# GBA      1.556664  0.112885  32.034829  0.048593  0.003524
# GBR      3.060843  0.164165  28.394439  0.107797  0.005782
# IDN     58.986258  2.178221  31.432592  1.876595  0.069298
# IL       6.612443  0.226370  30.558125  0.216389  0.007408
# IND      2.812757  0.184241  42.440127  0.066276  0.004341
# JPN      3.685084  0.256455  35.406606  0.104079  0.007243
# KOR      6.511931  0.399569  36.861012  0.176662  0.010840
# MYS     18.758253  0.893306  34.854012  0.538195  0.025630
# NOR      8.526997  0.311109  21.639577  0.394046  0.014377
# NY       5.324611  0.298020  27.826150  0.191353  0.010710
# NZL     15.356271  0.327276  24.713001  0.621384  0.013243
# QTP      5.185159  0.097448  48.651948  0.106577  0.002003
# SGP     10.282689  0.455299  48.452250  0.212223  0.009397
# TO       5.188509  0.378010  27.157566  0.191052  0.013919
# VAN     13.069561  0.648669  21.548501  0.606518  0.030103
# WA       5.449419  0.244446  22.750884  0.239526  0.010744
# YYN      4.285532  0.207690  39.145421  0.109477  0.005306

# %%
HOx.to_csv('I8 HOx.csv')
