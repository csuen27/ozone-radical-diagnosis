# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial']

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('/Users/csuen/Desktop/Sun-NG-24/radicals/representative regions/UKESM1-0-LL_2010_2014_representative_regions(ver240113).csv')

# %%
data
# Out:
#        index  longitude  latitude     t     loc_x            o3        o3prod  \
# 0         13      143.0     -37.0   1.0  142963.0  2.754085e-08  9.992185e-12
# 1         14      145.0     -37.0   1.0  144963.0  2.669592e-08  1.277102e-11
# 2         15      147.0     -37.0   1.0  146963.0  2.510329e-08  8.858626e-12
# 3       2428      143.0     -37.0   2.0  142963.0  2.183056e-08  7.131206e-12
# 4       2429      145.0     -37.0   2.0  144963.0  2.142809e-08  9.857071e-12
# ...      ...        ...       ...   ...       ...           ...           ...
# 9475  140953      103.0      25.0  59.0  103025.0  3.105605e-08  1.173194e-11
# 9476  143317      101.0      23.0  60.0  101023.0  3.027273e-08  1.016625e-11
# 9477  143318      103.0      23.0  60.0  103023.0  2.906724e-08  1.209996e-11
# 9478  143367      101.0      25.0  60.0  101025.0  2.749201e-08  8.076709e-12
# 9479  143368      103.0      25.0  60.0  103025.0  2.420598e-08  8.204462e-12
#
#             o3loss        eminox        emivoc  ...  pt6_prop  pt7_prop  \
# 0     2.069842e-12  1.555403e-11  8.936113e-11  ...  0.074310  0.008535
# 1     2.215572e-12  3.737211e-11  1.781655e-10  ...  0.019952  0.027364
# 2     1.947018e-12  1.626616e-11  3.480145e-10  ...  0.025903  0.087806
# 3     1.323975e-12  1.378624e-11  7.429800e-11  ...  0.070814  0.005471
# 4     1.406095e-12  3.743589e-11  1.317984e-10  ...  0.018933  0.013988
# ...            ...           ...           ...  ...       ...       ...
# 9475  1.008476e-12  9.193906e-11  1.351426e-10  ...  0.003967  0.192898
# 9476  1.124656e-12  2.665070e-11  1.221404e-10  ...  0.014645  0.304541
# 9477  1.130351e-12  4.070348e-11  1.152456e-10  ...  0.013181  0.267044
# 9478  7.250302e-13  5.260099e-11  9.281040e-11  ...  0.006236  0.205789
# 9479  6.305165e-13  8.898501e-11  9.067596e-11  ...  0.003188  0.192776
#
#       loc_y   seq  circle  placename  land_earth  land_global  CONTINENT  \
# 0     14516  6417     143  Australia           1            1  Australia
# 1     14606  6507     145  Australia           1            1  Australia
# 2     14696  6597     147  Australia           1            1  Australia
# 3     14516  6417     143  Australia           1            1  Australia
# 4     14606  6507     145  Australia           1            1  Australia
# ...     ...   ...     ...        ...         ...          ...        ...
# 9475  12747  4648     103      China           1            1       Asia
# 9476  12656  4557     101      China           1            1       Asia
# 9477  12746  4647     103      China           1            1       Asia
# 9478  12657  4558     101      China           1            1       Asia
# 9479  12747  4648     103      China           1            1       Asia
#
#       region
# 0        AUS
# 1        AUS
# 2        AUS
# 3        AUS
# 4        AUS
# ...      ...
# 9475     YYN
# 9476     YYN
# 9477     YYN
# 9478     YYN
# 9479     YYN
#
# [9480 rows x 179 columns]

# %% [markdown]
# #### 1-5. FNR: HCHO/NO${_2}$

# %%
data['hcho_no2'] = data['hcho_mole']/data['no2_mole']

data['nox_mole'] = data['no2_mole']+data['no_mole']

data['hno3_mole'] = data['hno3'] *1.01325*10**5/data['tas']*7.243*10**7*10**9
data['pan_mole']  = data['pan'] *1.01325*10**5/data['tas']*7.243*10**7*10**9

data['noz_mole'] = data['hno3_mole']+data['pan_mole']
data['noy_mole'] = data['nox_mole']+data['noz_mole']

data['hcho_noy'] = data['hcho_mole']/data['noy_mole']

data['o3_noy'] = data['o3_mole']/data['noy_mole']
data['o3_noz'] = data['o3_mole']/data['noz_mole']

data['o3_hno3'] = data['o3_mole']/data['hno3_mole']

data['voc_nox'] = data['emivoc']/data['eminox']

# %%
inds = data.groupby(['region']).mean()[['hcho_no2','hcho_noy','o3_noy','o3_noz','o3_hno3','voc_nox','LER']]
inds
# Out:
#         hcho_no2  hcho_noy     o3_noy      o3_noz     o3_hno3    voc_nox  \
# region
# AUS     0.442976  0.282332  11.123599   78.348094  104.177807   5.233270
# BRA     5.869522  3.453524  24.151586   93.137058  453.194832  98.626424
# BTH     0.047615  0.015405   0.304092    6.004306    6.344929   0.429687
# CA      0.134980  0.071310   2.316263   16.118406   17.759435   1.086755
# CCE     0.226974  0.105618   2.598999    9.756110   14.683449   3.022450
# COD     5.273861  2.704649  16.988368   53.687621  233.760075  86.086558
# DEU     0.094952  0.054576   2.628061   15.191645   17.000702   0.556930
# FIN     0.455269  0.230105  12.748106   47.411906   75.970755   3.494706
# FRA     0.226906  0.131786   5.987069   26.021356   31.295402   1.932617
# GBA     0.237045  0.111089   1.295822    7.481211    8.572826   2.103838
# GBR     0.108502  0.064022   4.627906   30.903726   36.600923   0.306912
# IDN     5.927087  2.867111  33.554898   87.687927  294.930062  36.453292
# IL      0.296764  0.169742   4.687445   22.484346   27.570771   1.686139
# IND     0.147860  0.074214   2.136151    9.833450   10.091980   1.059181
# JPN     0.234358  0.121686   5.258904   23.447180   27.142837   1.820136
# KOR     0.266569  0.119569   4.448822   13.016792   14.524548   1.790430
# MYS     2.936257  1.695635  13.689861   48.482019  193.649828  45.043435
# NOR     0.279831  0.151062   9.210977   48.410435   79.186370   3.623711
# NY      0.221182  0.122620   3.959138   20.699974   25.684581   1.456049
# NZL     0.740441  0.441752  27.756882  138.506624  206.801406   4.366043
# QTP     0.560524  0.214135  23.650469   67.233180  170.385746   8.752877
# SGP     0.978025  0.541341   5.336810   19.258195   26.870820   4.514295
# TO      0.243128  0.125996   4.841883   24.189514   30.277786   1.373477
# VAN     0.765477  0.400545  15.700589   66.991280  147.483276  21.588685
# WA      0.338525  0.198293   5.871210   42.419343   68.259338   5.851367
# YYN     0.448024  0.268266   4.654654   23.147363   46.200870   6.774341
#
#              LER
# region
# AUS     0.003500
# BRA     0.002365
# BTH     0.000107
# CA      0.000808
# CCE     0.000468
# COD     0.001716
# DEU     0.000667
# FIN     0.001663
# FRA     0.001783
# GBA     0.000206
# GBR     0.000886
# IDN     0.006366
# IL      0.001619
# IND     0.008098
# JPN     0.000745
# KOR     0.001091
# MYS     0.002614
# NOR     0.000903
# NY      0.001052
# NZL     0.006780
# QTP     0.053981
# SGP     0.001756
# TO      0.001151
# VAN     0.001344
# WA      0.000773
# YYN     0.000962

# %%
sens = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-radical/Main Analysis/extended indicators/region sensitivities.csv')
sens
# Out:
#    Region        Sn    Sn_err        Sv    Sv_err      SnSv      R2
# 0     BTH -9.901132  0.183759  4.863086  0.174193 -2.035977  0.8649
# 1     GBA  0.147599  0.099539  1.497546  0.056190  0.098561  0.9432
# 2     CCE  0.344900  0.084865  1.208617  0.033495  0.285367  0.8741
# 3     YYN  1.673687  0.722490  1.303109  0.111641  1.284380  0.8195
# 4     QTP  3.846261  0.129504  1.263858  0.040323  3.043270  0.9387
# 5     KOR -0.118734  0.239789  1.448416  0.076737 -0.081975  0.8943
# 6     JPN -0.115629  0.076568  1.353738  0.053426 -0.085415  0.8596
# 7     GBR -1.642956  0.112649  2.431756  0.110473 -0.675625  0.8225
# 8     FRA  0.466664  0.080890  1.024897  0.032964  0.455327  0.7047
# 9     DEU -1.182926  0.282724  2.000965  0.089983 -0.591178  0.8560
# 10    FIN  0.159276  0.331664  1.598572  0.108084  0.099636  0.7163
# 11    NOR -0.219742  0.538119  1.542800  0.107070 -0.142431  0.7399
# 12    SGP  0.717835  0.035367  0.643419  0.031659  1.115657  0.8766
# 13     NY  0.029098  0.228720  1.276946  0.087219  0.022788  0.8255
# 14     CA -0.437245  0.274061  1.664630  0.067024 -0.262668  0.8040
# 15     WA  0.218465  0.164937  1.445197  0.069399  0.151166  0.8269
# 16     IL  2.147033  0.608234  2.078860  0.099059  1.032793  0.8384
# 17     TO  0.565005  0.270984  2.389386  0.130860  0.236464  0.7170
# 18    VAN  0.876737  0.163293  1.189600  0.062292  0.737001  0.8101
# 19    AUS  0.678558  0.138674  0.729637  0.056665  0.929994  0.7189
# 20    IDN  0.571652  0.026554  0.283992  0.069377  2.012917  0.7134
# 21    NZL  1.471023  0.076959  1.820466  0.069801  0.808048  0.8644
# 22    COD  0.388597  0.018685  0.182689  0.144989  2.127096  0.8318
# 23    IND  0.851906  0.033557  0.483771  0.048610  1.760971  0.7449
# 24    BRA  1.039605  0.050838  0.376353  0.101639  2.762317  0.6515
# 25    MYS  0.891068  0.027572  0.764557  0.086396  1.165469  0.8668

# %%
inds = inds.merge(sens, how='left', left_on=['region'], right_on=['Region'])
inds
# Out:
#     hcho_no2  hcho_noy     o3_noy      o3_noz     o3_hno3    voc_nox  \
# 0   0.442976  0.282332  11.123599   78.348094  104.177807   5.233270
# 1   5.869522  3.453524  24.151586   93.137058  453.194832  98.626424
# 2   0.047615  0.015405   0.304092    6.004306    6.344929   0.429687
# 3   0.134980  0.071310   2.316263   16.118406   17.759435   1.086755
# 4   0.226974  0.105618   2.598999    9.756110   14.683449   3.022450
# 5   5.273861  2.704649  16.988368   53.687621  233.760075  86.086558
# 18  0.001052     NY  0.029098  0.228720  1.276946  0.087219  0.022788  0.8255
# 19  0.006780    NZL  1.471023  0.076959  1.820466  0.069801  0.808048  0.8644
# 20  0.053981    QTP  3.846261  0.129504  1.263858  0.040323  3.043270  0.9387
# 21  0.001756    SGP  0.717835  0.035367  0.643419  0.031659  1.115657  0.8766
# 22  0.001151     TO  0.565005  0.270984  2.389386  0.130860  0.236464  0.7170
# 23  0.001344    VAN  0.876737  0.163293  1.189600  0.062292  0.737001  0.8101
# 24  0.000773     WA  0.218465  0.164937  1.445197  0.069399  0.151166  0.8269
# 25  0.000962    YYN  1.673687  0.722490  1.303109  0.111641  1.284380  0.8195

# %%
inds['ln_hcho_no2'] = np.log(inds['hcho_no2'])
inds['ln_hcho_noy'] = np.log(inds['hcho_noy'])
inds['ln_o3_noy'] = np.log(inds['o3_noy'])
inds['ln_o3_noz'] = np.log(inds['o3_noz'])
inds['ln_o3_hno3'] = np.log(inds['o3_hno3'])
inds['ln_voc_nox'] = np.log(inds['voc_nox'])
inds['ln_LER'] = np.log(inds['LER'])

# %%
mod = LinearRegression()
X = inds[['ln_hcho_no2','ln_hcho_noy','ln_voc_nox','ln_LER']]
y = inds['SnSv']
mod.fit(X,y)
y_pred = mod.predict(X)
r2_score(y_pred, y)
# Out:
# 0.8107893024403766

# %%
mod2 = RandomForestRegressor()
X = inds[['ln_hcho_no2','ln_hcho_noy','ln_o3_noy','ln_o3_noz','ln_voc_nox','ln_LER']]
y = inds['SnSv']
mod2.fit(X,y)
y_pred = mod2.predict(X)
r2_score(y_pred, y)
# Out:
# 0.9303231356353293

# %%
inds['SnSv_adj'] = y_pred
inds
# Out:
#     hcho_no2  hcho_noy     o3_noy      o3_noz     o3_hno3    voc_nox  \
# 0   0.442976  0.282332  11.123599   78.348094  104.177807   5.233270
# 1   5.869522  3.453524  24.151586   93.137058  453.194832  98.626424
# 2   0.047615  0.015405   0.304092    6.004306    6.344929   0.429687
# 3   0.134980  0.071310   2.316263   16.118406   17.759435   1.086755
# 4   0.226974  0.105618   2.598999    9.756110   14.683449   3.022450
# 5   5.273861  2.704649  16.988368   53.687621  233.760075  86.086558
# 6   0.094952  0.054576   2.628061   15.191645   17.000702   0.556930
# 7   0.455269  0.230105  12.748106   47.411906   75.970755   3.494706
# 8   0.226906  0.131786   5.987069   26.021356   31.295402   1.932617
# 9   0.237045  0.111089   1.295822    7.481211    8.572826   2.103838
# 10  0.108502  0.064022   4.627906   30.903726   36.600923   0.306912
# 11  5.927087  2.867111  33.554898   87.687927  294.930062  36.453292
# 12  0.296764  0.169742   4.687445   22.484346   27.570771   1.686139
# 13  0.147860  0.074214   2.136151    9.833450   10.091980   1.059181
# 14  0.234358  0.121686   5.258904   23.447180   27.142837   1.820136
# 15  0.266569  0.119569   4.448822   13.016792   14.524548   1.790430
# 16  2.936257  1.695635  13.689861   48.482019  193.649828  45.043435
# 17  0.279831  0.151062   9.210977   48.410435   79.186370   3.623711
# 2     -4.173081  -1.190424   1.792477    1.847656   -0.844698 -9.146447
# 3     -2.640718   0.839955   2.779962    2.876917    0.083196 -7.121467
# 4     -2.247928   0.955126   2.277894    2.686721    1.106068 -7.666167
# 5      0.994972   2.832529   3.983182    5.454295    4.455353 -6.368006
# 6     -2.908154   0.966246   2.720746    2.833255   -0.585315 -7.313241
# 7     -1.469220   2.545383   3.858873    4.330348    1.251249 -6.399202
# 8     -2.026578   1.789602   3.258918    3.443471    0.658875 -6.329247
# 9     -2.197426   0.259145   2.012395    2.148597    0.743763 -8.486251
# 10    -2.748528   1.532105   3.430877    3.600073   -1.181193 -7.029114
# 11     1.053305   3.513183   4.473784    5.686738    3.596032 -5.056802
# 12    -1.773474   1.544888   3.112819    3.316756    0.522441 -6.426113
# 13    -2.600804   0.759006   2.285790    2.311741    0.057496 -4.816118
# 14    -2.106313   1.659923   3.154750    3.301113    0.598911 -7.202550
# 15    -2.123866   1.492639   2.566240    2.675840    0.582456 -6.820701
# 16     0.528057   2.616656   3.881193    5.266052    3.807627 -5.947041
# 17    -1.890063   2.220396   3.879715    4.371804    1.287499 -7.009605
# 18    -2.098665   1.376026   3.030132    3.245891    0.375727 -6.857060
# 19    -0.817006   3.323484   4.930918    5.331759    1.473857 -4.993823
# 20    -1.541151   3.163383   4.208167    5.138065    2.169382 -2.919127
# 21    -0.613706   1.674628   2.957937    3.291041    1.507249 -6.344492
# 22    -2.071505   1.577304   3.185919    3.410414    0.317346 -6.767262
# 23    -0.914930   2.753698   4.204562    4.993715    3.072169 -6.612213
# 24    -1.618009   1.770061   3.747604    4.223314    1.766675 -7.165607
# 25    -1.315777   1.537868   3.141881    3.832999    1.913142 -6.946356
#
#     SnSv_adj
# 0   1.049570
# 1   2.417502
# 2  -1.607389
# 3  -0.210824
# 4   0.181287
# 5   1.849077
# 6  -0.642820
# 7   0.381985
# 8   0.661291
# 9   0.080557
# 10 -0.639803
# 11  2.022161
# 12  0.778421
# 13  1.383281
# 14 -0.028256
# 15  0.001598
# 16  1.351333
# 17 -0.018475
# 18  0.104503
# 19  1.373155
# 20  2.440670
# 21  1.052466
# 22  0.170789
# 23  0.879902
# 24  0.251082
# 25  0.958702
#
# [26 rows x 22 columns]

# %%
plt.scatter(inds['ln_hcho_no2'], inds['SnSv_adj'])

# %%
plt.scatter(inds['ln_voc_nox'], inds['SnSv_adj'])

# %%
plt.scatter(inds['SnSv'], inds['SnSv_adj'])

# %% [markdown]
# #### Calculate the lumped equivalency ratios

# %%
list(data)
# Out:
# ['index',
#  'longitude',
#  'latitude',
#  't',
#  'loc_x',
#  'o3',
#  'o3prod',
#  'o3loss',
#  'eminox',
#  'emivoc',
#  'tas',
#  'hus',
#  'aod',
#  'bldep',
#  'ua',
#  'va',
#  'ps',
#  'jno2',
#  'photo1d',
#  'lossch4',
#  'lossco',
#  'no2',
#  'no',
#  'oh',
#  'h2o',
#  'pan',
#  'hno3',
#  'co',
#  'hcho',
#  'ch4',
#  'ch3o2_mod',
#  'ho2_mod',
#  'o1d_mod',
#  'o3_mole',
#  'no2_mole',
#  'no_mole',
#  'h2o_mole',
#  'co_mole',
#  'hcho_mole',
#  'oh_mole',
#  'n2_mole',
#  'o2_mole',
#  'lossco_mole',
#  'lossch4_mole',
#  'o1d_mole',
#  'ho2_mole',
#  'ch3o2_mole',
#  'ch3ooh_mole',
#  'o1d_mod_vmr',
#  'ho2_mod_vmr',
#  'ch3o2_mod_vmr',
#  'o1d_vmr',
#  'ho2_vmr',
#  'ch3o2_vmr',
#  'o1d_mod_mole',
#  'ho2_mod_mole',
#  'ch3o2_mod_mole',
#  'o1d_mole_adj',
#  'ho2_mole_adj',
#  'ch3o2_mole_adj',
#  'k1',
#  'k2',
#  'k3',
#  'k4',
#  'k5',
#  'k6',
#  'k7',
#  'k8',
#  'k9',
#  'k9a',
#  'k9b',
#  'k10',
#  'k11',
#  'k12',
#  'k13',
#  'k14',
#  'k15',
#  'k15a',
#  'k15b',
#  'k16',
#  'pt1',
#  'pt2',
#  'pt4',
#  'pt5',
#  'pt6',
#  'o3prod_mole',
#  'o3loss_mole',
#  'pt3',
#  'pt7',
#  'pt3_adj',
#  'pt7_adj',
#  'o3prod_mole_adj',
#  'o3loss_mole_adj',
#  'prop_pt1',
#  'prop_pt2',
#  'prop_pt3',
#  'prop_pt4',
#  'prop_pt5',
#  'prop_pt6',
#  'prop_pt7',
#  'diag_ch3o2_ch4',
#  'ch4_mole',
#  'o1d_vmr_adj',
#  'ho2_vmr_adj',
#  'ch3o2_vmr_adj',
#  'month',
#  'o1d_photo_prod',
#  'o1d_n2_loss',
#  'o1d_o2_loss',
#  'o1d_h2o_loss',
#  'oh_o1d_h2o_prod',
#  'oh_ho2_no_prod',
#  'oh_ho2_o3_prod',
#  'oh_co_loss',
#  'oh_ch4_loss',
#  'oh_hcho_loss',
#  'oh_ho2_loss',
#  'oh_o3_loss',
#  'oh_ch3ooh_loss',
#  'ho2_co_oh_prod',
#  'ho2_ch3o2_no_prod',
#  'ho2_oh_hcho_prod',
#  'ho2_oh_o3_prod',
#  'ho2_no_loss',
#  'ho2_o3_loss',
#  'ho2_ch3o2_loss',
#  'ho2_ho2_loss',
#  'ho2_oh_loss',
#  'ch3o2_oh_ch4_prod',
#  'ch3o2_oh_ch3ooh_prod',
#  'ch3o2_no_loss',
#  'ch3o2_ho2_loss',
#  'ch3o2_ch3o2_loss',
#  'c2h6',
#  'c3h8',
#  'isop',
#  'c2h6_mole',
#  'c3h8_mole',
#  'isop_mole',
#  'k17',
#  'k18',
#  'k19',
#  'k20',
#  'k21',
#  'k22',
#  'k23',
#  'k24a',
#  'k24b',
#  'k24',
#  'k25',
#  'k26',
#  'k27',
#  'etoo_mole',
#  'proo_mole',
#  'a',
#  'b',
#  'c',
#  'iso2_mole',
#  'prod_etoo_no',
#  'prod_proo_no',
#  'prod_iso2_no',
#  'loss_o3_isop',
#  'o3prod_mole_stacked',
#  'o3loss_mole_stacked',
#  'pt1_prop',
#  'pt2_prop',
#  'pt3_prop',
#  'pt4_prop',
#  'pt5_prop',
#  'pt6_prop',
#  'pt7_prop',
#  'loc_y',
#  'seq',
#  'circle',
#  'placename',
#  'land_earth',
#  'land_global',
#  'CONTINENT',
#  'region',
#  'hcho_no2',
#  'nox_mole',
#  'hno3_mole',
#  'pna_mole',
#  'pan_mole',
#  'noz_mole',
#  'noy_mole',
#  'hcho_noy',
#  'o3_noy',
#  'o3_noz',
#  'o3_hno3',
#  'voc_nox',
#  'pt3_total',
#  'pt7_total',
#  'EtOO_eq',
#  'ISOP_eq',
#  'LER']

# %%
data['pt3_total'] = data['o3prod_mole_stacked'] - data['pt1'] - data['pt2']
data['pt7_total'] = data['o3loss_mole_stacked'] - data['pt4'] - data['pt5'] - data['pt6']

# %%
data['EtOO_eq'] = data['pt3_total']/data['k18']/data['no_mole']
data['ISOP_eq'] = data['pt7_total']/data['k27']/data['o3_mole']

# %%
data['LER'] = data['EtOO_eq']/data['ISOP_eq']

# %%
ler = data.groupby(['region']).mean()[['LER']]
ler
# Out:
#              LER
# region
# AUS     0.003500
# BRA     0.002365
# BTH     0.000107
# CA      0.000808
# CCE     0.000468
# COD     0.001716
# DEU     0.000667
# FIN     0.001663
# FRA     0.001783
# GBA     0.000206
# GBR     0.000886
# IDN     0.006366
# IL      0.001619
# IND     0.008098
# JPN     0.000745
# KOR     0.001091
# MYS     0.002614
# NOR     0.000903
# NY      0.001052
# NZL     0.006780
# QTP     0.053981
# SGP     0.001756
# TO      0.001151
# VAN     0.001344
# WA      0.000773
# YYN     0.000962

# %%
plt.scatter(inds['ln_LER'], inds['SnSv_adj'])

# %%
ext = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-radical/Main Analysis/extended indicators/region dynamic indicators.csv')
ext
# Out:
#    ABBR  ∂[OH]/∂[HO2]  ∂[HO2]/∂[OH]  ∂[CH3O2]/∂[OH]  ∂[HO2]/∂[OH]/[O3]  \
# 0   BTH      0.962423      0.281922        0.032699           0.012633
# 1   GBA      0.148226      1.375367        0.159336           0.042720
# 2   CCE      0.066035      1.170644        0.095569           0.033880
# 3   YYN      0.060690      2.898264        0.397886           0.072236
# 4   QTP      0.060377      4.090988        0.905716           0.076823
# 5   KOR      0.084173      6.620707        1.138212           0.174006
# 6   JPN      0.084889      3.192535        0.497475           0.086973
# 7   GBR      0.205846      3.033261        0.828510           0.101798
# 8   FRA      0.133097      5.012556        1.277960           0.161399
# 9   DEU      0.347008      2.561511        0.641043           0.097999
# 10  FIN      0.048126     14.347110        3.846293           0.599217
# 11  NOR      0.091705      8.968996        2.253629           0.385730
# 12   NY      0.135927      5.370567        0.938924           0.184778
# 13   CA      0.259529      2.777202        0.653918           0.082711
# 14   WA      0.122802      5.378138        1.003924           0.225004
# 15   IL      0.122943      7.006939        1.288932           0.222701
# 16   TO      0.118973      4.822863        0.934239           0.169732
# 25  0.448024  0.268266   4.654654   23.147363   46.200870   6.774341
#
#          LER Region        Sn    Sn_err  ...  ∂[HO2]/∂[OH]_x  \
# 0   0.003500    AUS  0.678558  0.138674  ...        8.305997
# 1   0.002365    BRA  1.039605  0.050838  ...       34.796960
# 2   0.000107    BTH -9.901132  0.183759  ...        0.281922
# 3   0.000808     CA -0.437245  0.274061  ...        2.777202
# 4   0.000468    CCE  0.344900  0.084865  ...        1.170644
# 5   0.001716    COD  0.388597  0.018685  ...       24.983630
# 6   0.000667    DEU -1.182926  0.282724  ...        2.561511
# 7   0.001663    FIN  0.159276  0.331664  ...       14.347110
# 8   0.001783    FRA  0.466664  0.080890  ...        5.012556
# 9   0.000206    GBA  0.147599  0.099539  ...        1.375367
# 10  0.000886    GBR -1.642956  0.112649  ...        3.033261
# 11  0.006366    IDN  0.571652  0.026554  ...       50.578420
# 12  0.001619     IL  2.147033  0.608234  ...        7.006939
# 13  0.008098    IND  0.851906  0.033557  ...        3.875101
# 14  0.000745    JPN -0.115629  0.076568  ...        3.192535
# 15  0.001091    KOR -0.118734  0.239789  ...        6.620707
# 16  0.002614    MYS  0.891068  0.027572  ...        8.991059
# 17  0.000903    NOR -0.219742  0.538119  ...        8.968996
# 18  0.001052     NY  0.029098  0.228720  ...        5.370567
# 19  0.006780    NZL  1.471023  0.076959  ...       12.092500
# 20  0.053981    QTP  3.846261  0.129504  ...        4.090988
# 21  0.001756    SGP  0.717835  0.035367  ...             NaN
# 22  0.001151     TO  0.565005  0.270984  ...        4.822863
# 23  0.001344    VAN  0.876737  0.163293  ...       10.935780
# 24  0.000773     WA  0.218465  0.164937  ...        5.378138
# 25  0.000962    YYN  1.673687  0.722490  ...        2.898264
#
#     ∂[CH3O2]/∂[OH]_x  ∂[HO2]/∂[OH]/[O3]_x  ABBR_y  ∂[OH]/∂[HO2]_y  \
# 0           2.721709                 0.37     AUS        0.060796
# 1           8.248690                 1.61     BRA        0.023308
# 2           0.032699                 0.01     BTH        0.962423
# 3           0.653918                 0.08      CA        0.259529
# 4           0.095569                 0.03     CCE        0.066035
# 5           0.226906                 0.84     COD        0.005910
# 6           0.641043                 0.10     DEU        0.347008
# 7           3.846293                 0.60     FIN        0.048126
# 8           1.277960                 0.16     FRA        0.133097
# 9           0.159336                 0.04     GBA        0.148226
# 10          0.828510                 0.10     GBR        0.205846
# 11         11.366780                 1.62     IDN        0.010277
# 12          1.288932                 0.22      IL        0.122943
# 13          1.137152                 0.09     IND        0.153362
# 14          0.497475                 0.09     JPN        0.084889
# 15          1.138212                 0.17     KOR        0.084173
# 16          1.117835                 0.26     MYS        0.016472
# 17          2.253629                 0.39     NOR        0.091705
# 18          0.938924                 0.18      NY        0.135927
# 19          4.281207                 0.47     NZL        0.064656
# 20          0.905716                 0.08     QTP        0.060377
# 21               NaN                  NaN     NaN             NaN
# 22          0.934239                 0.17      TO        0.118973
# 23          2.002896                 0.48     VAN        0.045579
# 24          1.003924                 0.23      WA        0.122802
# 25          0.397886                 0.07     YYN        0.060690
#
#     ∂[HO2]/∂[OH]_y  ∂[CH3O2]/∂[OH]_y  ∂[HO2]/∂[OH]/[O3]_y  ∂[OH]/∂[HO2]*[O3]  \
# 0         8.305997          2.721709             0.365523              1.382
# 1        34.796960          8.248690             1.612063              0.503
# 2         0.281922          0.032699             0.012633             21.478
# 3         2.777202          0.653918             0.082711              8.714
# 4         1.170644          0.095569             0.033880              2.282
# 5        24.983630          0.226906             0.840762              0.176
# 6         2.561511          0.641043             0.097999              9.070
# 7        14.347110          3.846293             0.599217              1.152
# 8         5.012556          1.277960             0.161399              4.134
# 9         1.375367          0.159336             0.042720              4.772
# 10        3.033261          0.828510             0.101798              6.134
# 11       50.578420         11.366780             1.622202              0.320
# 12        7.006939          1.288932             0.222701              3.868
# 13        3.875101          1.137152             0.092551              6.421
# 14        3.192535          0.497475             0.086973              3.116
# 15        6.620707          1.138212             0.174006              3.203
# 16        8.991059          1.117835             0.259906              0.570
# 17        8.968996          2.253629             0.385730              2.132
# 18        5.370567          0.938924             0.184778              3.951
# 19       12.092500          4.281207             0.470689              1.661
# 20        4.090988          0.905716             0.076823              3.215
# 21             NaN               NaN                  NaN                NaN
# 22        4.822863          0.934239             0.169732              3.381
# 23       10.935780          2.002896             0.476142              1.047
# 24        5.378138          1.003924             0.225004              2.935
# 25        2.898264          0.397886             0.072236              2.435
#
#        o3
# 0   22.72
# 1   21.59
# 2   22.32
# 3   33.58
# 4   34.55
# 5   29.72
# 6   26.14
# 7   23.94
# 8   31.06
# 9   32.20
# 10  29.80
# 11  31.18
# 12  31.46
# 13  41.87
# 14  36.71
# 15  38.05
# 16  34.59
# 17  23.25
# 18  29.07
# 19  25.69
# 20  53.25
# 21    NaN
# 22  28.41
# 23  22.97
# 24  23.90
# 25  40.12
#
# [26 rows x 34 columns]

# %%
plt.scatter(np.log(inds['∂[HO2]/∂[OH]/[O3]']), inds['SnSv_adj'])

# %%
plt.scatter(np.log(inds['∂[HO2]/∂[OH]']), inds['SnSv_adj'])

# %%
plt.scatter(np.log(inds['∂[OH]/∂[HO2]*[O3]']), inds['SnSv_adj'])

# %%
plt.scatter(np.log(inds['∂[CH3O2]/∂[OH]']), inds['SnSv_adj'])

# %%
data['o3'].mean()
# Out:
# 3.5355558148396646e-08

# %%
data['ch4'].mean()
# Out:
# 1.8145415492616006e-06

# %%
data['hcho'].mean()
# Out:
# 1.3321952456393467e-09

# %%
y.shape
# Out:
# (26,)

# %%
mod = LinearRegression()
X = inds[['ln_hcho_no2']]
y = inds['SnSv']
mod.fit(X,y)
y_pred = mod.predict(X)
r2_score(y_pred, y)

import statsmodels.api as sm
ols = sm.OLS(y, X)
ols_result = ols.fit()
# Now you have at your disposition several error estimates, e.g.
ols_result.HC0_se
# Out:
# ln_hcho_no2    0.154419
# dtype: float64

# %%
X.mean()
# Out:
# ln_hcho_no2   -0.865036
# dtype: float64
