# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial']
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
dataset = pd.read_csv('D://Research/radicals/UKESM1-0-LL_2010_2014(ver240110).csv')

# %%
land = pd.read_csv('C://Users/Haitong/OneDrive - National University of Singapore/Documents/Manuscripts/Sun-NG-25/global_grid_2x2_label_continent.csv')
dataset_land = dataset.merge(land, how='left', left_on=['longitude','latitude'], right_on=['longitude','latitude'])
dataset_land = dataset_land[dataset_land['land_global']==1]

# %%
list(dataset_land)
# Out:
# ['longitude',
#  'latitude',
#  't',
#  'loc_x',
#  'o3',
#  'o3prod',
#  'o3loss',
#  'eminox',
#  'emivoc',
#  'tas',
#  'hus',
#  'aod',
#  'bldep',
#  'ua',
#  'va',
#  'ps',
#  'jno2',
#  'photo1d',
#  'lossch4',
#  'lossco',
#  'no2',
#  'no',
#  'oh',
#  'h2o',
#  'pan',
#  'hno3',
#  'co',
#  'hcho',
#  'ch4',
#  'ch3o2_mod',
#  'ho2_mod',
#  'o1d_mod',
#  'o3_mole',
#  'no2_mole',
#  'no_mole',
#  'h2o_mole',
#  'co_mole',
#  'hcho_mole',
#  'oh_mole',
#  'n2_mole',
#  'o2_mole',
#  'lossco_mole',
#  'lossch4_mole',
#  'o1d_mole',
#  'ho2_mole',
#  'ch3o2_mole',
#  'ch3ooh_mole',
#  'o1d_mod_vmr',
#  'ho2_mod_vmr',
#  'ch3o2_mod_vmr',
#  'o1d_vmr',
#  'ho2_vmr',
#  'ch3o2_vmr',
#  'o1d_mod_mole',
#  'ho2_mod_mole',
#  'ch3o2_mod_mole',
#  'o1d_mole_adj',
#  'ho2_mole_adj',
#  'ch3o2_mole_adj',
#  'k1',
#  'k2',
#  'k3',
#  'k4',
#  'k5',
#  'k6',
#  'k7',
#  'k8',
#  'k9',
#  'k9a',
#  'k9b',
#  'k10',
#  'k11',
#  'k12',
#  'k13',
#  'k14',
#  'k15',
#  'k15a',
#  'k15b',
#  'k16',
#  'pt1',
#  'pt2',
#  'pt4',
#  'pt5',
#  'pt6',
#  'o3prod_mole',
#  'o3loss_mole',
#  'pt3',
#  'pt7',
#  'pt3_adj',
#  'pt7_adj',
#  'o3prod_mole_adj',
#  'o3loss_mole_adj',
#  'prop_pt1',
#  'prop_pt2',
#  'prop_pt3',
#  'prop_pt4',
#  'prop_pt5',
#  'prop_pt6',
#  'prop_pt7',
#  'diag_ch3o2_ch4',
#  'ch4_mole',
#  'o1d_vmr_adj',
#  'ho2_vmr_adj',
#  'ch3o2_vmr_adj',
#  'month',
#  'o1d_photo_prod',
#  'o1d_n2_loss',
#  'o1d_o2_loss',
#  'o1d_h2o_loss',
#  'oh_o1d_h2o_prod',
#  'oh_ho2_no_prod',
#  'oh_ho2_o3_prod',
#  'oh_co_loss',
#  'oh_ch4_loss',
#  'oh_hcho_loss',
#  'oh_ho2_loss',
#  'oh_o3_loss',
#  'oh_ch3ooh_loss',
#  'ho2_co_oh_prod',
#  'ho2_ch3o2_no_prod',
#  'ho2_oh_hcho_prod',
#  'ho2_oh_o3_prod',
#  'ho2_no_loss',
#  'ho2_o3_loss',
#  'ho2_ch3o2_loss',
#  'ho2_ho2_loss',
#  'ho2_oh_loss',
#  'ch3o2_oh_ch4_prod',
#  'ch3o2_oh_ch3ooh_prod',
#  'ch3o2_no_loss',
#  'ch3o2_ho2_loss',
#  'ch3o2_ch3o2_loss',
#  'c2h6',
#  'c3h8',
#  'isop',
#  'c2h6_mole',
#  'c3h8_mole',
#  'isop_mole',
#  'k17',
#  'k18',
#  'k19',
#  'k20',
#  'k21',
#  'k22',
#  'k23',
#  'k24a',
#  'k24b',
#  'k24',
#  'k25',
#  'k26',
#  'k27',
#  'etoo_mole',
#  'proo_mole',
#  'a',
#  'b',
#  'c',
#  'iso2_mole',
#  'prod_etoo_no',
#  'prod_proo_no',
#  'prod_iso2_no',
#  'loss_o3_isop',
#  'o3prod_mole_stacked',
#  'o3loss_mole_stacked',
#  'pt1_prop',
#  'pt2_prop',
#  'pt3_prop',
#  'pt4_prop',
#  'pt5_prop',
#  'pt6_prop',
#  'pt7_prop',
#  'loc_y',
#  'seq',
#  'circle',
#  'placename',
#  'land_earth',
#  'land_global',
#  'CONTINENT']

# %%
dataset_land['o3net_mole'] = dataset_land['o3prod_mole'] - dataset_land['o3loss_mole']

# %%
dataset_land['o3net_mole'].median()
# Out:
# 1114606.668596

# %%
list(dataset_land)
# Out:
# ['longitude',
#  'latitude',
#  't',
#  'loc_x',
#  'o3',
#  'o3prod',
#  'o3loss',
#  'eminox',
#  'emivoc',
#  'tas',
#  'hus',
#  'aod',
#  'bldep',
#  'ua',
#  'va',
#  'ps',
#  'jno2',
#  'photo1d',
#  'lossch4',
#  'lossco',
#  'no2',
#  'no',
#  'oh',
#  'h2o',
#  'pan',
#  'hno3',
#  'co',
#  'hcho',
#  'ch4',
#  'ch3o2_mod',
#  'ho2_mod',
#  'o1d_mod',
#  'o3_mole',
#  'no2_mole',
#  'no_mole',
#  'h2o_mole',
#  'co_mole',
#  'hcho_mole',
#  'oh_mole',
#  'n2_mole',
#  'o2_mole',
#  'lossco_mole',
#  'lossch4_mole',
#  'o1d_mole',
#  'ho2_mole',
#  'ch3o2_mole',
#  'ch3ooh_mole',
#  'o1d_mod_vmr',
#  'ho2_mod_vmr',
#  'ch3o2_mod_vmr',
#  'o1d_vmr',
#  'ho2_vmr',
#  'ch3o2_vmr',
#  'o1d_mod_mole',
#  'ho2_mod_mole',
#  'ch3o2_mod_mole',
#  'o1d_mole_adj',
#  'ho2_mole_adj',
#  'ch3o2_mole_adj',
#  'k1',
#  'k2',
#  'k3',
#  'k4',
#  'k5',
#  'k6',
#  'k7',
#  'k8',
#  'k9',
#  'k9a',
#  'k9b',
#  'k10',
#  'k11',
#  'k12',
#  'k13',
#  'k14',
#  'k15',
#  'k15a',
#  'k15b',
#  'k16',
#  'pt1',
#  'pt2',
#  'pt4',
#  'pt5',
#  'pt6',
#  'o3prod_mole',
#  'o3loss_mole',
#  'pt3',
#  'pt7',
#  'pt3_adj',
#  'pt7_adj',
#  'o3prod_mole_adj',
#  'o3loss_mole_adj',
#  'prop_pt1',
#  'prop_pt2',
#  'prop_pt3',
#  'prop_pt4',
#  'prop_pt5',
#  'prop_pt6',
#  'prop_pt7',
#  'diag_ch3o2_ch4',
#  'ch4_mole',
#  'o1d_vmr_adj',
#  'ho2_vmr_adj',
#  'ch3o2_vmr_adj',
#  'month',
#  'o1d_photo_prod',
#  'o1d_n2_loss',
#  'o1d_o2_loss',
#  'o1d_h2o_loss',
#  'oh_o1d_h2o_prod',
#  'oh_ho2_no_prod',
#  'oh_ho2_o3_prod',
#  'oh_co_loss',
#  'oh_ch4_loss',
#  'oh_hcho_loss',
#  'oh_ho2_loss',
#  'oh_o3_loss',
#  'oh_ch3ooh_loss',
#  'ho2_co_oh_prod',
#  'ho2_ch3o2_no_prod',
#  'ho2_oh_hcho_prod',
#  'ho2_oh_o3_prod',
#  'ho2_no_loss',
#  'ho2_o3_loss',
#  'ho2_ch3o2_loss',
#  'ho2_ho2_loss',
#  'ho2_oh_loss',
#  'ch3o2_oh_ch4_prod',
#  'ch3o2_oh_ch3ooh_prod',
#  'ch3o2_no_loss',
#  'ch3o2_ho2_loss',
#  'ch3o2_ch3o2_loss',
#  'c2h6',
#  'c3h8',
#  'isop',
#  'c2h6_mole',
#  'c3h8_mole',
#  'isop_mole',
#  'k17',
#  'k18',
#  'k19',
#  'k20',
#  'k21',
#  'k22',
#  'k23',
#  'k24a',
#  'k24b',
#  'k24',
#  'k25',
#  'k26',
#  'k27',
#  'etoo_mole',
#  'proo_mole',
#  'a',
#  'b',
#  'c',
#  'iso2_mole',
#  'prod_etoo_no',
#  'prod_proo_no',
#  'prod_iso2_no',
#  'loss_o3_isop',
#  'o3prod_mole_stacked',
#  'o3loss_mole_stacked',
#  'pt1_prop',
#  'pt2_prop',
#  'pt3_prop',
#  'pt4_prop',
#  'pt5_prop',
#  'pt6_prop',
#  'pt7_prop',
#  'loc_y',
#  'seq',
#  'circle',
#  'placename',
#  'land_earth',
#  'land_global',
#  'CONTINENT',
#  'o3net_mole']

# %%
dataset_land_grid = dataset_land.groupby('loc_x').mean(numeric_only =True)[['eminox','emivoc']]
dataset_land_grid.to_csv('emission grid-average.csv')
emis_ave = pd.read_csv('emission grid-average.csv')
emis_ave = emis_ave.rename(columns={"eminox": "eminox_ave", "emivoc": "emivoc_ave"})

# %%
dataset_land = dataset_land.merge(emis_ave, how='left', left_on=['loc_x'], right_on=['loc_x'])
dataset_land
# Out:
#         longitude  latitude     t     loc_x            o3        o3prod  \
# 0            69.0     -49.0   1.0   68951.0  1.471148e-08  3.211922e-13
# 1           169.0     -45.0   1.0  168955.0  1.456359e-08  2.490233e-12
# 2           171.0     -45.0   1.0  170955.0  1.623399e-08  4.713648e-12
# 3           147.0     -43.0   1.0  146957.0  1.990147e-08  4.032379e-12
# 4           171.0     -43.0   1.0  170957.0  1.529586e-08  2.395443e-12
# ...           ...       ...   ...       ...           ...           ...
# 232315      -35.0      83.0  60.0  325083.0  1.944581e-08  1.879754e-16
# 232316      -31.0      83.0  60.0  329083.0  1.909269e-08  2.111646e-16
# 232317      -29.0      83.0  60.0  331083.0  1.874725e-08  2.106560e-16
# 232318      -27.0      83.0  60.0  333083.0  1.836742e-08  2.978477e-17
# 232319      -25.0      83.0  60.0  335083.0  1.764124e-08  2.634068e-17
#
#               o3loss        eminox        emivoc        tas  ...  loc_y  \
# 0       2.722755e-13  6.111121e-13  8.230395e-12  279.33667  ...  11180
# 1       6.123487e-13  6.684854e-12  1.961126e-10  286.22003  ...  15682
# 2       7.773185e-13  5.938116e-12  1.148444e-10  286.87515  ...  15772
# 3       1.018624e-12  6.746558e-12  1.089857e-10  288.73615  ...  14693
# 4       7.764943e-13  5.167356e-12  2.154613e-10  288.01100  ...  15773
# ...              ...           ...           ...        ...  ...    ...
# 232315  3.207016e-16  8.447100e-14  4.913423e-16  235.54500  ...   6566
# 232316  2.945706e-16  9.493963e-14  9.205029e-16  235.85202  ...   6746
# 232317  1.801800e-16  1.413331e-13  1.779273e-15  235.96560  ...   6836
# 232318  1.012632e-16  4.734165e-14  3.160282e-17  235.80554  ...   6926
# 232319  8.617270e-17  4.823964e-14  1.935247e-16  236.87338  ...   7016
#
#           seq  circle                          placename  land_earth  \
# 0        3081      69  French Southern & Antarctic Lands           1
# 1        7583     169                        New Zealand           1
# 2        7673     171                        New Zealand           1
# 3        6594     147                          Australia           1
# 4        7674     171                        New Zealand           1
# ...       ...     ...                                ...         ...
# 232315  14667     325                          Greenland           1
# 232316  14847     329                          Greenland           1
# 232317  14937     331                          Greenland           1
# 232318  15027     333                          Greenland           1
# 232319  15117     335                          Greenland           1
#
#         land_global      CONTINENT    o3net_mole    eminox_ave    emivoc_ave
# 0                 1     Antarctica  2.945764e+04  6.125379e-13  4.646854e-12
# 1                 1        Oceania  1.130862e+06  6.565225e-12  8.799238e-11
# 2                 1        Oceania  2.370458e+06  6.050911e-12  5.023277e-11
# 3                 1      Australia  1.814883e+06  7.110824e-12  5.226175e-11
# 4                 1        Oceania  9.749310e+05  5.398532e-12  9.574584e-11
# ...             ...            ...           ...           ...           ...
# 232315            1  North America -7.992770e+01  8.372332e-14  5.026281e-16
# 232316            1  North America -5.022706e+01  9.517656e-14  9.416517e-16
# 232317            1  North America  1.835267e+01  1.409455e-13  1.816621e-15
# 232318            1  North America -4.304430e+01  4.550616e-14  3.231475e-17
# 232319            1  North America -3.603084e+01  4.740708e-14  1.962160e-16
#
# [232320 rows x 180 columns]

# %%
dataset_land['eminox_p'] = dataset_land['eminox']/dataset_land['eminox_ave']
dataset_land['emivoc_p'] = dataset_land['emivoc']/dataset_land['emivoc_ave']

dataset_land['N'] = dataset_land['eminox_p']
dataset_land['N2'] = dataset_land['eminox_p']**2
dataset_land['NV'] = dataset_land['eminox_p']*dataset_land['emivoc_p']
dataset_land['V'] = dataset_land['emivoc_p']
dataset_land['V2'] = dataset_land['emivoc_p']**2

# %%
dataset_land = dataset_land.dropna()

# %%
coef = dataset_land.groupby('loc_x').apply(lambda g: sm.OLS(endog=g['o3net_mole']*10**(-6), exog=g[['N2','N','NV','V2','V']]).fit().params)

coord = pd.DataFrame()
coord['ann'] = coef['N2']
coord['an'] = coef['N']
coord['anv'] = coef['NV']
coord['avv'] = coef['V2']
coord['av'] = coef['V']

# %%
coef['Sn'] = 2*coef['N2'] + coef['N'] + coef['NV']
coef['Sv'] = 2*coef['V2'] + coef['V'] + coef['NV']

# %%
coef['p_N2'] = 2*coef['N2']/coef['Sn']
coef['p_N']  = coef['N']/coef['Sn']
coef['p_NV1'] = coef['NV']/coef['Sn']

coef['p_V2'] = 2*coef['V2']/coef['Sv']
coef['p_V']  = coef['V']/coef['Sv']
coef['p_NV2'] = coef['NV']/coef['Sv']

# %%
coef
# Out:
#                 N2          N         NV        V2          V
# loc_x
# 1007.0    0.113318   9.647246  -3.780474  2.164773  -1.653977
# 1009.0   -0.997983   5.266131   2.581082 -0.636601   1.245033
# 1011.0   -0.087201  -0.881979   2.025000 -3.211171   7.734734
# 1013.0   -9.061084  11.289771  10.035921  2.755015 -10.477642
# 1015.0   -9.902236   6.950207  15.470794 -3.928376  -4.661132
# ...            ...        ...        ...       ...        ...
# 359045.0 -0.874591   0.526862  -1.085031 -0.049164   4.613812
# 359047.0  0.516674  -2.313066  -1.373303 -0.510684   6.899645
# 359049.0  0.260425  -1.782257  -0.898855 -0.176486   5.162889
# 359051.0  6.467584  -8.582138  -8.637461  0.435463  12.215514
# 359053.0  4.174678  -5.425867  -4.494633  0.928060   6.067494
#
# [3810 rows x 5 columns]

# %%
np.nanpercentile(coef['p_N2'],50)
# Out:
# -0.05523664601925281

# %%
np.nanpercentile(coef['p_N'],50)
# Out:
# 0.5381958879467132

# %%
np.nanpercentile(coef['p_NV1'],50)
# Out:
# 0.3010348304795708

# %%
np.nanpercentile(coef['p_V2'],50)
# Out:
# -0.33098630185549605

# %%
np.nanpercentile(coef['p_V'],50)
# Out:
# 0.7659166963491393

# %%
np.nanpercentile(coef['p_NV2'],50)
# Out:
# 0.6443509618555007

# %%
coef['N'].mean()
# Out:
# 1.1200092952983995

# %%
coef['NV'].mean()
# Out:
# 1.6679194082349713

# %%
coef['V2'].mean()
# Out:
# -0.5079086093292822

# %%
coef['V'].mean()
# Out:
# 1.5247474588704952

# %%
coord['Sn_adj'] = (coord['Sn']-np.nanpercentile(coord['Sn'],5))*2

# %%
np.nanpercentile(coord['Sn_adj'],10)
# Out:
# 1.1971699176977106

# %%
coord['Sv_adj'] = coord['Sv']

# %%
#coord['Sn_adj'] = Sn - np.nanpercentile(coord['Sn'],10)
coord['SnSv_adj'] = coord['Sn_adj']/coord['Sv']

# %%
np.nanpercentile(coord['Sn_adj'],1)
# Out:
# -6.340144377183305

# %%
plt.figure(num=None, figsize=(20, 2.75), dpi=100, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu')
x = coord['longitude']
y = coord['latitude']

plt.subplot(1,3,1)
plt.title('Sn', fontsize = 20, fontname = "Arial", color = "black")
z = coord['Sn_adj']
sc = plt.scatter(x, y, c=z, marker="s", vmin=-5, vmax=5, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
plt.colorbar(fraction=0.02)

# %%
plt.figure(num=None, figsize=(20, 2.75), dpi=100, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu')
x = coord['longitude']
y = coord['latitude']

plt.subplot(1,3,1)
plt.title('SnSv', fontsize = 20, fontname = "Arial", color = "black")
z = coord['SnSv_adj']
sc = plt.scatter(x, y, c=z, marker="s", vmin=-1, vmax=2, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
plt.colorbar(fraction=0.02)

# %%
temp = coord

plt.figure(num=None, figsize=(20, 2.75), dpi=100, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('Reds')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('Sv', fontsize = 20, fontname = "Arial", color = "black")
z = (temp['Sv_adj'])
sc = plt.scatter(x, y, c=z, marker="s",s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %%
coord
# Out:
#           longitude  latitude            Sn            Sv      SnSv       FNR  \
# loc_x
# 1007.0          1.0       7.0  4.643417e+06  1.491373e+06  3.113518  0.847337
# 1009.0          1.0       9.0  4.758675e+06  1.633897e+06  2.912470  1.031314
# 1011.0          1.0      11.0  1.966960e+06  2.992600e+06  0.657275  0.971161
# 1013.0          1.0      13.0  4.613372e+05  3.831023e+06  0.120421  0.857094
# 1015.0          1.0      15.0  1.305974e+06  2.407488e+06  0.542463  0.890078
# ...             ...       ...           ...           ...       ...       ...
# 359045.0       -1.0      45.0  6.752232e+03  2.943472e+06  0.002294  0.344742
# 359047.0       -1.0      47.0 -8.245514e+05  3.630210e+06 -0.227136  0.170657
# 359049.0       -1.0      49.0 -1.167805e+06  3.579772e+06 -0.326223  0.118948
# 359051.0       -1.0      51.0 -2.463285e+06  4.397630e+06 -0.560139  0.066409
# 359053.0       -1.0      53.0 -2.186617e+06  3.735408e+06 -0.585376  0.038085
#
#                HOP  LER_etoo  LER_isop    Sv_adj     Sn_adj  SnSv_adj
# loc_x
# 1007.0    0.588327  0.001990  0.136939  1.491373  10.503281  7.042691
# 1009.0    0.455310  0.004121  0.576027  1.633897  10.733796  6.569445
# 1011.0    0.600245  0.002400  0.199374  2.992600   5.150366  1.721034
# 1013.0    0.708265  0.000656  0.020673  3.831023   2.139121  0.558368
# 1015.0    0.762063  0.000474  0.010954  2.407488   3.828394  1.590203
# ...            ...       ...       ...       ...        ...       ...
# 359045.0  0.354096  0.000573  0.156564  2.943472   1.229951  0.417857
# 359047.0  0.225052  0.000050  0.012392  3.630210  -0.432657 -0.119182
# 359049.0  0.155709  0.000025  0.008964  3.579772  -1.119163 -0.312635
# 359051.0  0.073641  0.000005  0.004809  4.397630  -3.710123 -0.843664
# 359053.0  0.039491  0.000001  0.002939  3.735408  -3.156789 -0.845099
#
# [3810 rows x 12 columns]

# %%
coord['FNR_NO2'] = FNR_NO2_map['FNR_NO2']
coord['FNR_NOy'] = fnr_noy_map['FNR_NOy']
coord['FNR_NOx'] = FNR_NOx_map['FNR_NOx']

# %%
coord.to_csv('regime diagnosis map.csv', index=False)

# %%
coef = dataset_land.groupby('loc_x').apply(lambda g: sm.OLS(g['o3net_mole'], g[['N','V']]).fit().params)
coef['SnSv'] = coef['N']/coef['V']
coord['Sn'] = coef['N'] 
coord['Sv'] = coef['V']
coord['SnSv'] = coef['SnSv']

# %%
coef = dataset_land.groupby('loc_x').apply(lambda g: sm.OLS(g['o3net_mole'], g[['NV','N','V']]).fit().params)

# %%
coef['Sn'] = coef['NV'] + coef['N']
coef['Sv'] = coef['NV'] + coef['V']
coef['SnSv'] = coef['Sn']/coef['Sv']

# %%
coord = dataset_land.groupby(['loc_x']).mean()[['longitude','latitude']]

# %%
coord['Sn'] = coef['Sn']
coord['Sv'] = coef['Sv']
coord['SnSv'] = coef['SnSv']

# %%
temp = coord

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('SnSv', fontsize = 20, fontname = "Arial", color = "black")
z = (temp['SnSv'])
sc = plt.scatter(x, y, c=z, marker="s", vmin=-1, vmax=3, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %%
sens_country
# Out:
# ['longitude',
#  'latitude',
#  't',
#  'loc_x',
#  'o3',
#  'o3prod',
#  'o3loss',
#  'eminox',
#  'emivoc',
#  'tas',
#  'hus',
#  'aod',
#  'bldep',
#  'ua',
#  'va',
#  'ps',
#  'jno2',
#  'photo1d',
#  'lossch4',
#  'lossco',
#  'no2',
#  'no',
#  'oh',
#  'h2o',
#  'pan',
#  'hno3',
#  'co',
#  'hcho',
#  'ch4',
#  'ch3o2_mod',
#  'ho2_mod',
#  'o1d_mod',
#  'o3_mole',
#  'no2_mole',
#  'no_mole',
#  'h2o_mole',
#  'co_mole',
#  'hcho_mole',
#  'oh_mole',
#  'n2_mole',
#  'o2_mole',
#  'lossco_mole',
#  'lossch4_mole',
#  'o1d_mole',
#  'ho2_mole',
#  'ch3o2_mole',
#  'ch3ooh_mole',
#  'o1d_mod_vmr',
#  'ho2_mod_vmr',
#  'ch3o2_mod_vmr',
#  'o1d_vmr',
#  'ho2_vmr',
#  'ch3o2_vmr',
#  'o1d_mod_mole',
#  'ho2_mod_mole',
#  'ch3o2_mod_mole',
#  'o1d_mole_adj',
#  'ho2_mole_adj',
#  'ch3o2_mole_adj',
#  'k1',
#  'k2',
#  'k3',
#  'k4',
#  'k5',
#  'k6',
#  'k7',
#  'k8',
#  'k9',
#  'k9a',
#  'k9b',
#  'k10',
#  'k11',
#  'k12',
#  'k13',
#  'k14',
#  'k15',
#  'k15a',
#  'k15b',
#  'k16',
#  'pt1',
#  'pt2',
#  'pt4',
#  'pt5',
#  'pt6',
#  'o3prod_mole',
#  'o3loss_mole',
#  'pt3',
#  'pt7',
#  'pt3_adj',
#  'pt7_adj',
#  'o3prod_mole_adj',
#  'o3loss_mole_adj',
#  'prop_pt1',
#  'prop_pt2',
#  'prop_pt3',
#  'prop_pt4',
#  'prop_pt5',
#  'prop_pt6',
#  'prop_pt7',
#  'diag_ch3o2_ch4',
#  'ch4_mole',
#  'o1d_vmr_adj',
#  'ho2_vmr_adj',
#  'ch3o2_vmr_adj',
#  'month',
#  'o1d_photo_prod',
#  'o1d_n2_loss',
#  'o1d_o2_loss',
#  'o1d_h2o_loss',
#  'oh_o1d_h2o_prod',
#  'oh_ho2_no_prod',
#  'oh_ho2_o3_prod',
#  'oh_co_loss',
#  'oh_ch4_loss',
#  'oh_hcho_loss',
#  'oh_ho2_loss',
#  'oh_o3_loss',
#  'oh_ch3ooh_loss',
#  'ho2_co_oh_prod',
#  'ho2_ch3o2_no_prod',
#  'ho2_oh_hcho_prod',
#  'ho2_oh_o3_prod',
#  'ho2_no_loss',
#  'ho2_o3_loss',
#  'ho2_ch3o2_loss',
#  'ho2_ho2_loss',
#  'ho2_oh_loss',
#  'ch3o2_oh_ch4_prod',
#  'ch3o2_oh_ch3ooh_prod',
#  'ch3o2_no_loss',
#  'ch3o2_ho2_loss',
#  'ch3o2_ch3o2_loss',
#  'c2h6',
#  'c3h8',
#  'isop',
#  'c2h6_mole',
#  'c3h8_mole',
#  'isop_mole',
#  'k17',
#  'k18',
#  'k19',
#  'k20',
#  'k21',
#  'k22',
#  'k23',
#  'k24a',
#  'k24b',
#  'k24',
#  'k25',
#  'k26',
#  'k27',
#  'etoo_mole',
#  'proo_mole',
#  'a',
#  'b',
#  'c',
#  'iso2_mole',
#  'prod_etoo_no',
#  'prod_proo_no',
#  'prod_iso2_no',
#  'loss_o3_isop',
#  'o3prod_mole_stacked',
#  'o3loss_mole_stacked',
#  'pt1_prop',
#  'pt2_prop',
#  'pt3_prop',
#  'pt4_prop',
#  'pt5_prop',
#  'pt6_prop',
#  'pt7_prop',
#  'loc_y',
#  'seq',
#  'circle',
#  'placename',
#  'land_earth',
#  'land_global',
#  'CONTINENT',
#  'o3net_mole',
#  'eminox_ave',
#  'emivoc_ave',
#  'eminox_p',
#  'emivoc_p',
#  'N',
#  'N2',
#  'NV',
#  'V',
#  'V2']

# %%
dataset_land['placename']
# Out:
# 0         French Southern & Antarctic Lands
# 1                               New Zealand
# 2                               New Zealand
# 3                                 Australia
# 4                               New Zealand
#                         ...
# 232315                            Greenland
# 232316                            Greenland
# 232317                            Greenland
# 232318                            Greenland
# 232319                            Greenland
# Name: placename, Length: 228600, dtype: object

# %% [markdown]
# #### FNR(NOy)

# %%
dataset_land['NOx'] = dataset_land['no2_mole']+dataset_land['no_mole']

dataset_land['hno3_mole'] = dataset_land['hno3']*1.01325*10**5/dataset['tas']*7.243*10**7*10**9
dataset_land['pan_mole'] = dataset_land['pan']*1.01325*10**5/dataset['tas']*7.243*10**7*10**9

dataset_land['NOz'] = dataset_land['hno3_mole']+dataset_land['pan_mole']
dataset_land['NOy'] = dataset_land['NOx']+dataset_land['NOz']

dataset_land['FNR_NOy'] = dataset_land['hcho_mole']/dataset_land['NOy']

# %%
fnr_noy_map = dataset_land.groupby(['loc_x']).mean()[['longitude','latitude','FNR_NOy']]

# %%
temp = fnr_noy_map ## 我们以FNR(NOy)作为标准结果来与其他方法进行比对

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('SnSv', fontsize = 20, fontname = "Arial", color = "black")
z = np.log(temp['FNR_NOy'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %%
fnr_noy_map['FNR_NOy'].mean()
# Out:
# 0.7328727483539509

# %%
fnr_noy_map['FNR_NOy'].max()
# Out:
# 6.7192278966518835

# %%
np.nanpercentile(fnr_noy_map['FNR_NOy'],1)
# Out:
# 0.037101324605241966

# %%
np.nanpercentile(fnr_noy_map['FNR_NOy'],99)
# Out:
# 4.7347307743403615

# %%
a = 0.12
b = 0.20
c = 0.50

fnr_noy_map['regime1'] = (np.sign(fnr_noy_map['FNR_NOy']-a)+1)/2
fnr_noy_map['regime2'] = (np.sign(fnr_noy_map['FNR_NOy']-b)+1)/2
fnr_noy_map['regime3'] = (np.sign(fnr_noy_map['FNR_NOy']-c)+1)/2
fnr_noy_map['regime'] = fnr_noy_map['regime1']+fnr_noy_map['regime2']+fnr_noy_map['regime3']+1

# %%
temp = fnr_noy_map ## 我们以FNR(NOy)作为标准结果来与其他方法进行比对

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('Reds_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('SnSv', fontsize = 20, fontname = "Arial", color = "black")
z = np.log(temp['regime'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %% [markdown]
# #### FNR(NOx)

# %%
dataset_land['NOx'] = dataset_land['no2_mole']+dataset_land['no_mole']
dataset_land['FNR_NOx'] = dataset_land['hcho_mole']/dataset_land['NOx']

# %%
FNR_NOx_map = dataset_land.groupby(['loc_x']).mean()[['longitude','latitude','FNR_NOx']]

# %%
temp = FNR_NOx_map

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('FNR(NOx)', fontsize = 10, fontname = "Arial", color = "black")
z = np.log(temp['FNR_NOx'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %% [markdown]
# #### FNR(NO2)

# %%
dataset_land['FNR_NO2'] = dataset_land['hcho_mole']/dataset_land['no2_mole']

FNR_NO2_map = dataset_land.groupby(['loc_x']).mean()[['longitude','latitude','FNR_NO2']]

temp = FNR_NO2_map

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('FNR(NO2)', fontsize = 10, fontname = "Arial", color = "black")
z = np.log(temp['FNR_NO2'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %% [markdown]
# #### HOP

# %%
d_ho2_oh_beta = dataset_land.groupby('loc_x').apply(lambda g: sm.OLS(g['ho2_mole'], g[['oh_mole']]).fit().params)
d_ho2_oh_beta
# Out:
#             oh_mole
# loc_x
# 1007.0    21.602808
# 1009.0    17.197077
# 1011.0    24.672509
# 1013.0    31.034167
# 1015.0    34.035714
# ...             ...
# 359045.0  11.444687
# 359047.0   7.242937
# 359049.0   5.050276
# 359051.0   2.160534
# 359053.0   0.905095
#
# [3810 rows x 1 columns]

# %%
hop = dataset_land.groupby('loc_x').mean()[['longitude','latitude','o3']]
hop
# Out:
#           longitude  latitude            o3
# loc_x
# 1007.0          1.0       7.0  3.671902e-08
# 1009.0          1.0       9.0  3.777001e-08
# 1011.0          1.0      11.0  4.110404e-08
# 1013.0          1.0      13.0  4.381718e-08
# 1015.0          1.0      15.0  4.466261e-08
# ...             ...       ...           ...
# 359045.0       -1.0      45.0  3.232083e-08
# 359047.0       -1.0      47.0  3.218338e-08
# 359049.0       -1.0      49.0  3.243398e-08
# 359051.0       -1.0      51.0  2.933875e-08
# 359053.0       -1.0      53.0  2.291879e-08
#
# [3810 rows x 3 columns]

# %%
hop['d_ho2_oh'] = d_ho2_oh_beta['oh_mole']
hop['HOP'] = hop['d_ho2_oh']/(hop['o3']*10**9)
hop
# Out:
#           longitude  latitude            o3   d_ho2_oh       HOP
# loc_x
# 1007.0          1.0       7.0  3.671902e-08  21.602808  0.588327
# 1009.0          1.0       9.0  3.777001e-08  17.197077  0.455310
# 1011.0          1.0      11.0  4.110404e-08  24.672509  0.600245
# 1013.0          1.0      13.0  4.381718e-08  31.034167  0.708265
# 1015.0          1.0      15.0  4.466261e-08  34.035714  0.762063
# ...             ...       ...           ...        ...       ...
# 359045.0       -1.0      45.0  3.232083e-08  11.444687  0.354096
# 359047.0       -1.0      47.0  3.218338e-08   7.242937  0.225052
# 359049.0       -1.0      49.0  3.243398e-08   5.050276  0.155709
# 359051.0       -1.0      51.0  2.933875e-08   2.160534  0.073641
# 359053.0       -1.0      53.0  2.291879e-08   0.905095  0.039491
#
# [3810 rows x 5 columns]

# %%
temp = hop

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('HOP', fontsize = 10, fontname = "Arial", color = "black")
z = np.log(temp['HOP'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %%
#### LER(EtOOeq)

# %%
dataset_land['pt3'] = dataset_land['o3prod_mole_stacked'] - dataset_land['pt1'] - dataset_land['pt2']
dataset_land['pt7'] = dataset_land['o3loss_mole_stacked'] - dataset_land['pt4'] - dataset_land['pt5'] - dataset_land['pt6']

dataset_land['etoo_eq'] = dataset_land['pt3']/dataset_land['k18']/dataset_land['no_mole']
dataset_land['isop_eq'] = dataset_land['pt7']/dataset_land['k27']/dataset_land['o3_mole']

dataset_land['nox_mole'] = dataset_land['no_mole'] + dataset_land['no2_mole']

dataset_land['LER_etoo'] = dataset_land['etoo_eq']/dataset_land['nox_mole']
dataset_land['LER_isop'] = dataset_land['isop_eq']/dataset_land['nox_mole']

# %%
LER_etoo_map = dataset_land.groupby(['loc_x']).mean()[['longitude','latitude','LER_etoo']]
LER_isop_map = dataset_land.groupby(['loc_x']).mean()[['longitude','latitude','LER_isop']]

# %%
plt.scatter(np.log(coord['FNR']), coord['SnSv'])

# %%
temp = LER_etoo_map 

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('LER_etoo', fontsize = 10, fontname = "Arial", color = "black")
z = np.log(temp['LER_etoo'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %%
temp = LER_isop_map 

plt.figure(num=None, figsize=(20, 2.75), dpi=200, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('RdYlBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('LER_isop', fontsize = 10, fontname = "Arial", color = "black")
z = np.log(temp['LER_isop'])
sc = plt.scatter(x, y, c=z, marker="s", s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 75])
#plt.colorbar(fraction=0.02)
# Out:
# (-60.0, 75.0)

# %%
coord
# Out:
#           longitude  latitude            Sn            Sv      SnSv
# loc_x
# 1007.0          1.0       7.0  3.694551e+06  3.991420e+06  0.925623
# 1009.0          1.0       9.0  3.142076e+06  5.228414e+06  0.600962
# 1011.0          1.0      11.0  2.761940e+05  4.951608e+06  0.055779
# 1013.0          1.0      13.0  1.220270e+06  2.494013e+06  0.489280
# 1015.0          1.0      15.0  1.813671e+06  1.325750e+06  1.368035
# ...             ...       ...           ...           ...       ...
# 359045.0       -1.0      45.0 -1.033870e+06  5.089830e+06 -0.203125
# 359047.0       -1.0      47.0 -9.111044e+05  3.386652e+06 -0.269028
# 359049.0       -1.0      49.0 -1.181798e+06  3.253025e+06 -0.363292
# 359051.0       -1.0      51.0 -2.159322e+06  3.714117e+06 -0.581382
# 359053.0       -1.0      53.0 -1.906472e+06  3.136293e+06 -0.607874
#
# [3810 rows x 5 columns]

# %%
coord['FNR'] = FNR_NOx_map['FNR_NOx']
coord['HOP'] = hop['HOP']
coord['LER_etoo'] = LER_etoo_map['LER_etoo']
coord['LER_isop'] = LER_isop_map['LER_isop']

# %%
coord
# Out:
#           longitude  latitude            Sn            Sv      SnSv       FNR  \
# loc_x
# 1007.0          1.0       7.0  3.694551e+06  3.991420e+06  0.925623  0.847337
# 1009.0          1.0       9.0  3.142076e+06  5.228414e+06  0.600962  1.031314
# 1011.0          1.0      11.0  2.761940e+05  4.951608e+06  0.055779  0.971161
# 1013.0          1.0      13.0  1.220270e+06  2.494013e+06  0.489280  0.857094
# 1015.0          1.0      15.0  1.813671e+06  1.325750e+06  1.368035  0.890078
# ...             ...       ...           ...           ...       ...       ...
# 359045.0       -1.0      45.0 -1.033870e+06  5.089830e+06 -0.203125  0.344742
# 359047.0       -1.0      47.0 -9.111044e+05  3.386652e+06 -0.269028  0.170657
# 359049.0       -1.0      49.0 -1.181798e+06  3.253025e+06 -0.363292  0.118948
# 359051.0       -1.0      51.0 -2.159322e+06  3.714117e+06 -0.581382  0.066409
# 359053.0       -1.0      53.0 -1.906472e+06  3.136293e+06 -0.607874  0.038085
#
#                HOP  LER_etoo  LER_isop
# loc_x
# 1007.0    0.588327  0.001990  0.136939
# 1009.0    0.455310  0.004121  0.576027
# 1011.0    0.600245  0.002400  0.199374
# 1013.0    0.708265  0.000656  0.020673
# 1015.0    0.762063  0.000474  0.010954
# ...            ...       ...       ...
# 359045.0  0.354096  0.000573  0.156564
# 359047.0  0.225052  0.000050  0.012392
# 359049.0  0.155709  0.000025  0.008964
# 359051.0  0.073641  0.000005  0.004809
# 359053.0  0.039491  0.000001  0.002939
#
# [3810 rows x 9 columns]

# %%
coord['Sv_adj'].min()
# Out:
# -7.136975075662172
