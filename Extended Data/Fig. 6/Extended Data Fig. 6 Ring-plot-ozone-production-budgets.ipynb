# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['Arial']

# %%
o3prod = pd.read_csv('Fig. 2 o3prod.csv')

# %%
o3prod_colors = ['darkslategrey','palegoldenrod','turquoise']

R=0.75
r1=0.2

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
labels = ['HO${_2}$+NO','CH${_3}$O${_2}$+NO','RO${_2}$+NO']
budgets_JJA = o3prod['NA_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=labels, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_JJA = o3prod['NA_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6a-1 Production Rate North America (JJA).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_JJA = o3prod['SA_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6a-2 Production Rate South America (JJA).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_JJA = o3prod['EU_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6a-3 Production Rate Europe (JJA).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_JJA = o3prod['AF_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6a-4 Production Rate Africa (JJA).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_JJA = o3prod['AS_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6a-5 Production Rate Asia (JJA).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_JJA = o3prod['OC_JJA'].values
centre=[1]

ax.pie(budgets_JJA, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6a-6 Production Rate Oceania (JJA).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_DJF = o3prod['NA_DJF'].values
centre=[1]

ax.pie(budgets_DJF, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6b-1 Production Rate North America (DJF).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_DJF = o3prod['SA_DJF'].values
centre=[1]

ax.pie(budgets_DJF, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6b-2 Production Rate South America (DJF).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_DJF = o3prod['EU_DJF'].values
centre=[1]

ax.pie(budgets_DJF, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6b-3 Production Rate Europe (DJF).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_DJF = o3prod['AF_DJF'].values
centre=[1]

ax.pie(budgets_DJF, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6b-4 Production Rate Africa (DJF).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_DJF = o3prod['AS_DJF'].values
centre=[1]

ax.pie(budgets_DJF, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6b-5 Production Rate Asia (DJF).pdf", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=75)
budgets_DJF = o3prod['OC_DJF'].values
centre=[1]

ax.pie(budgets_DJF, radius=R, labels=None, colors=o3prod_colors, startangle=90)
ax.pie(centre, radius=R-r1,colors='w')

fig.savefig("Extended Data Fig. 6b-6 Production Rate Oceania (DJF).pdf", bbox_inches="tight")
