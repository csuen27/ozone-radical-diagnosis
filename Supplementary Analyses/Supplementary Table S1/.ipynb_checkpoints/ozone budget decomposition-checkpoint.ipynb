# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = pd.read_csv('D://Research/radicals/UKESM1-0-LL_2010_2014(ver240109).csv')

# %%
dataset['k1'] = 2.15*10**(-11)*np.exp(110/dataset['tas'])
dataset['k2'] = 3.30*10**(-11)*np.exp(55/dataset['tas'])
dataset['k3'] = 1.63*10**(-10)*np.exp(60/dataset['tas'])
dataset['k4'] = 4.30*10**(-32)*(dataset['tas']/300)**(-1.2)*dataset['n2_mole']
#dataset['k4'] = 1.00*10**(-12)
dataset['k5'] = 1.44*10**(-13)

dataset['k6'] = 5.40*10**(-12)*np.exp(135/dataset['tas'])
dataset['k7'] = 1.70*10**(-12)*np.exp(-940/dataset['tas'])
dataset['k8'] = 2.45*10**(-12)*np.exp(-600/dataset['tas'])
dataset['k9'] = 4.01*10**(-12)*np.exp(190/dataset['tas'])
dataset['k9a'] = 2.12*10**(-12)*np.exp(190/dataset['tas'])
dataset['k9b'] = 1.89*10**(-12)*np.exp(190/dataset['tas'])

dataset['k10'] = 3.30*10**(-12)*np.exp(270/dataset['tas'])
dataset['k11'] = 2.03*10**(-16)*(dataset['tas']/300)**4.57*np.exp(693/dataset['tas'])
dataset['k12'] = 3.00*10**(-13)*np.exp(460/dataset['tas'])
dataset['k13'] = 4.80*10**(-11)*np.exp(250/dataset['tas'])

dataset['k14'] = 2.30*10**(-12)*np.exp(360/dataset['tas'])
dataset['k15'] = 3.80*10**(-13)*np.exp(780/dataset['tas'])
dataset['k15a'] = dataset['k15']/(1+498*np.exp(-1160/dataset['tas']))
dataset['k15b'] = dataset['k15']-dataset['k15a']
dataset['k16'] = 1.03*10**(-13)*np.exp(365/dataset['tas'])

dataset['k17'] = 6.90*10**(-12)*np.exp(-1000/dataset['tas'])
dataset['k18'] = 2.55*10**(-12)*np.exp(380/dataset['tas'])
dataset['k19'] = 6.40*10**(-13)*np.exp(710/dataset['tas'])
dataset['k20'] = 7.60*10**(-12)*np.exp(-585/dataset['tas'])
dataset['k21'] = 2.90*10**(-12)*np.exp(350/dataset['tas'])
dataset['k22'] = 1.51*10**(-13)*np.exp(1300/dataset['tas'])
dataset['k23'] = 2.70*10**(-11)*np.exp(390/dataset['tas'])
#dataset['k24'] = 1.12*10**(-13)*np.exp(360/dataset['tas'])
dataset['k24'] = 2.54*10**(-12)*np.exp(360/dataset['tas'])
dataset['k25'] = 2.05*10**(-13)*np.exp(1300/dataset['tas'])
dataset['k26'] = 2.00*10**(-12)
dataset['k27'] = 9.99*10**(-15)*np.exp(-1995/dataset['tas'])

# %%
dataset['pt1'] = dataset['k10']*dataset['ho2_mole']*dataset['no_mole']
dataset['pt2'] = dataset['k14']*dataset['ch3o2_mole']*dataset['no_mole']
dataset['pt3'] = dataset['o3prod_mole_stacked'] - dataset['pt1'] - dataset['pt2']

dataset['pt4'] = dataset['k3']*dataset['o1d_mole']*dataset['h2o_mole']
dataset['pt5'] = dataset['k7']*dataset['oh_mole']*dataset['o3_mole']
dataset['pt6'] = dataset['k11']*dataset['ho2_mole']*dataset['o3_mole']
dataset['pt7'] = dataset['o3loss_mole_stacked'] - dataset['pt4'] - dataset['pt5'] - dataset['pt6']

# %%
dataset['pt1_prop'] = dataset['pt1']/dataset['o3prod_mole_stacked']
dataset['pt2_prop'] = dataset['pt2']/dataset['o3prod_mole_stacked']
dataset['pt3_prop'] = dataset['pt3']/dataset['o3prod_mole_stacked']

dataset['pt4_prop'] = dataset['pt4']/dataset['o3loss_mole_stacked']
dataset['pt5_prop'] = dataset['pt5']/dataset['o3loss_mole_stacked']
dataset['pt6_prop'] = dataset['pt6']/dataset['o3loss_mole_stacked']
dataset['pt7_prop'] = dataset['pt7']/dataset['o3loss_mole_stacked']

# %%
dataset['o3prod_mole_stacked'].mean()
# Out:
# 1684811.8512441546

# %%
dataset['o3loss_mole_stacked'].mean()
# Out:
# 639519.4764388478

# %%
land = pd.read_csv('/Users/csuen/Documents/GitHub/ozone-budget/global_grid_2x2_label_continent.csv')
dataset_land = dataset.merge(land, how='left', left_on=['longitude','latitude'], right_on=['longitude','latitude'])
dataset_land = dataset_land[dataset_land['land_global']==1]

# %%
temp = dataset_land.groupby('loc_x').mean()

plt.figure(num=None, figsize=(12, 2.75), dpi=75, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('YlGnBu_r')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,2,1)
plt.title('Production Rate', fontsize = 12, fontname = "Arial", color = "black")
z = temp['o3prod_mole_stacked']*10**(-7)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=4, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,2,2)
plt.title('Loss Rate', fontsize = 12, fontname = "Arial", color = "black")
z = temp['o3loss_mole_stacked']*10**(-6)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=4, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

# %%
plt.figure(num=None, figsize=(20, 3), dpi=75, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('Reds')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('HO${_2}$+NO', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt1']*10**(-6))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,3,2)
plt.title('CH${_3}$O${_2}$+NO', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt2']*10**(-6))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,3,3)
plt.title('RO${_2}$+NO', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt3']*10**(-6))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=2, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

# %%
plt.figure(num=None, figsize=(20, 3), dpi=75, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('Reds')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,3,1)
plt.title('HO${_2}$+NO', fontsize = 12, fontname = "Arial", color = "black")
z = temp['pt1_prop']
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=1, s=1.75, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,3,2)
plt.title('CH${_3}$O${_2}$+NO', fontsize = 12, fontname = "Arial", color = "black")
z = temp['pt2_prop']
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=1, s=1.75, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,3,3)
plt.title('RO${_2}$+NO', fontsize = 12, fontname = "Arial", color = "black")
z = temp['pt3_prop']
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, vmax=1, s=1.75, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

# %%
plt.figure(num=None, figsize=(20, 2.5), dpi=75, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('Reds')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,4,1)
plt.title('O(${^1}$D)+H${_2}$O', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt4']*10**(-5))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,4,2)
plt.title('O${_3}$+OH', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt5']*10**(-5))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,4,3)
plt.title('O${_3}$+HO${_2}$', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt6']*10**(-5))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,4,4)
plt.title('O${_3}$+VOCs', fontsize = 12, fontname = "Arial", color = "black")
z = (temp['pt7']*10**(-5))
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

# %%
def Pearson_correlation(X,Y):
	if len(X)==len(Y):
		Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
		Sum_x_squared = sum((X-X.mean())**2)
		Sum_y_squared = sum((Y-Y.mean())**2)	 
		corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
	return corr

# %%
Pearson_correlation(dataset_land['o3prod_mole_stacked'], dataset_land['o3loss_mole_stacked'])
# Out:
# 0.7608090129995694

# %%
print(temp['o3prod_mole_stacked'].mean())
# Out:
# 4934663.054742577

# %%
print(temp['o3loss_mole_stacked'].mean())
# Out:
# 835226.2450608012

# %%
print(dataset_land['pt1'].mean())
print(dataset_land['pt2'].mean())
print(dataset_land['pt3'].mean())
# Out:
# 1354696.6647138793
# 275636.24880508485
# 3304330.1412236374

# %%
print(dataset_land['pt4'].mean())
print(dataset_land['pt5'].mean())
print(dataset_land['pt6'].mean())
print(dataset_land['pt7'].mean())
# Out:
# 453074.3963938859
# 91530.43567670013
# 74597.75273388399
# 216023.66025632666

# %%
print(dataset_land['pt1_prop'].mean())
print(dataset_land['pt2_prop'].mean())
print(dataset_land['pt3_prop'].mean())
# Out:
# 0.4725273364492952
# 0.12578544936271818
# 0.40168721418799497

# %%
print(dataset_land['pt1_prop'].median())
print(dataset_land['pt2_prop'].median())
print(dataset_land['pt3_prop'].median())
# Out:
# 0.5153375625212813
# 0.1106358201500291
# 0.32993729673793837

# %%
print(dataset_land['pt4_prop'].mean())
print(dataset_land['pt5_prop'].mean())
print(dataset_land['pt6_prop'].mean())
print(dataset_land['pt7_prop'].mean())
# Out:
# 0.483601882246794
# 0.15312192349251252
# 0.19107217080210387
# 0.1722040234585862

# %%
print(dataset_land['pt4_prop'].median())
print(dataset_land['pt5_prop'].median())
print(dataset_land['pt6_prop'].median())
print(dataset_land['pt7_prop'].median())
# Out:
# 0.5029952707985245
# 0.13266944038129214
# 0.08558610196562273
# 0.07870916231817722

# %% [markdown]
# ### Explore the seasonal variability

# %%
dataset_JJA = dataset_land[dataset_land['month']>5]
dataset_JJA = dataset_JJA[dataset_JJA['month']<9]

# %%
dataset_JJA['o3prod_mole_stacked'].mean()
# Out:
# 7215928.818163668

# %%
dataset_JJA['o3loss_mole_stacked'].mean()
# Out:
# 1199452.9870825205

# %%
temp = dataset_JJA.groupby('loc_x').mean()

plt.figure(num=None, figsize=(10, 2.25), dpi=75, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('viridis')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,2,1)
plt.title('Production Rate', fontsize = 12, fontname = "Arial", color = "black")
z = temp['o3prod_mole_stacked']*10**(-7)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,2,2)
plt.title('Loss Rate', fontsize = 12, fontname = "Arial", color = "black")
z = temp['o3loss_mole_stacked']*10**(-6)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

# %%
print(dataset_JJA['o3prod_mole_stacked'].mean())
print(dataset_JJA['pt1_prop'].mean())
print(dataset_JJA['pt2_prop'].mean())
print(dataset_JJA['pt3_prop'].mean())
# Out:
# 7215928.818163668
# 0.3484892137935422
# 0.10919424255947734
# 0.5423165436469732

# %%
print(dataset_JJA['o3loss_mole_stacked'].mean())
print(dataset_JJA['pt4_prop'].mean())
print(dataset_JJA['pt5_prop'].mean())
print(dataset_JJA['pt6_prop'].mean())
print(dataset_JJA['pt7_prop'].mean())
# Out:
# 1199452.9870825205
# 0.5315159594562585
# 0.12117639859370481
# 0.13440623838885288
# 0.21290140356117956

# %%
dataset_DJF = dataset_land[dataset_land['month']<3]

# %%
dataset_DJF['o3prod_mole_stacked'].mean()
# Out:
# 3583855.0094602657

# %%
dataset_DJF['o3loss_mole_stacked'].mean()
# Out:
# 592094.1012036521

# %%
temp = dataset_DJF.groupby('loc_x').mean()

plt.figure(num=None, figsize=(10, 2.25), dpi=75, facecolor='w', edgecolor='k')
cm = plt.cm.get_cmap('viridis')
x = temp['longitude']
y = temp['latitude']

plt.subplot(1,2,1)
plt.title('Production Rate', fontsize = 12, fontname = "Arial", color = "black")
z = temp['o3prod_mole_stacked']*10**(-7)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

plt.subplot(1,2,2)
plt.title('Loss Rate', fontsize = 12, fontname = "Arial", color = "black")
z = temp['o3loss_mole_stacked']*10**(-6)
sc = plt.scatter(x, y, c=z, marker="s", vmin=0, s=1, cmap=cm)
plt.xlim([-180, 180])
plt.ylim([-60, 90])
plt.colorbar(fraction=0.02)

# %%
print(dataset_DJF['o3prod_mole_stacked'].mean())
print(dataset_DJF['pt1_prop'].mean())
print(dataset_DJF['pt2_prop'].mean())
print(dataset_DJF['pt3_prop'].mean())
# Out:
# 3583855.0094602657
# 0.581447627851855
# 0.12811807467699912
# 0.2904342974711434

# %%
print(dataset_DJF['o3loss_mole_stacked'].mean())
print(dataset_DJF['pt4_prop'].mean())
print(dataset_DJF['pt5_prop'].mean())
print(dataset_DJF['pt6_prop'].mean())
print(dataset_DJF['pt7_prop'].mean())
# Out:
# 592094.1012036521
# 0.4676350316529191
# 0.16970583528541802
# 0.21069819457055905
# 0.15196093849109868

# %% [markdown]
# #### Observe the regional variability

# %%
dataset_NA = dataset_land[dataset_land['CONTINENT']=="North America"]
dataset_SA = dataset_land[dataset_land['CONTINENT']=="South America"]
dataset_EU = dataset_land[dataset_land['CONTINENT']=="Europe"]
dataset_AS = dataset_land[dataset_land['CONTINENT']=="Asia"]
dataset_AF = dataset_land[dataset_land['CONTINENT']=="Africa"]
dataset_OC = dataset_land[dataset_land['CONTINENT']=="Oceania"]
dataset_AS = dataset_land[dataset_land['CONTINENT']=="Australia"]
dataset_OC = dataset_OC.append(dataset_AS)

# %%
print(dataset_NA['o3prod_mole_stacked'].mean())
print(dataset_NA['pt1_prop'].mean())
print(dataset_NA['pt2_prop'].mean())
print(dataset_NA['pt3_prop'].mean())
# Out:
# 2561266.4886776623
# 0.5055783782458626
# 0.15393907758175332
# 0.34048254417237894

# %%
dataset_NA_JJA = dataset_NA[dataset_NA['month']>5]
dataset_NA_JJA = dataset_NA_JJA[dataset_NA_JJA['month']<9]
print(dataset_NA_JJA['pt1_prop'].mean())
print(dataset_NA_JJA['pt2_prop'].mean())
print(dataset_NA_JJA['pt3_prop'].mean())
# Out:
# 0.3438023299775554
# 0.11831649341450365
# 0.537881176607942

# %%
dataset_NA_DJF = dataset_NA[dataset_NA['month']<3]
print(dataset_NA_DJF['pt1_prop'].mean())
print(dataset_NA_DJF['pt2_prop'].mean())
print(dataset_NA_DJF['pt3_prop'].mean())
# Out:
# 0.6463966605285195
# 0.18058323780453797
# 0.17302010166694407

# %%
print(dataset_SA['o3prod_mole_stacked'].mean())
print(dataset_SA['pt1_prop'].mean())
print(dataset_SA['pt2_prop'].mean())
print(dataset_SA['pt3_prop'].mean())
# Out:
# 9681702.428540993
# 0.15046267069921193
# 0.03589796833616409
# 0.8136393609646243

# %%
dataset_SA_JJA = dataset_SA[dataset_SA['month']>5]
dataset_SA_JJA = dataset_SA_JJA[dataset_SA_JJA['month']<9]
print(dataset_SA_JJA['pt1_prop'].mean())
print(dataset_SA_JJA['pt2_prop'].mean())
print(dataset_SA_JJA['pt3_prop'].mean())
# Out:
# 0.17808429697295786
# 0.03921061340405266
# 0.7827050896229893

# %%
dataset_SA_DJF = dataset_SA[dataset_SA['month']<3]
print(dataset_SA_DJF['pt1_prop'].mean())
print(dataset_SA_DJF['pt2_prop'].mean())
print(dataset_SA_DJF['pt3_prop'].mean())
# Out:
# 0.10767284824968032
# 0.027931161841801864
# 0.8643959899085192

# %%
print(dataset_EU['o3prod_mole_stacked'].mean())
print(dataset_EU['pt1_prop'].mean())
print(dataset_EU['pt2_prop'].mean())
print(dataset_EU['pt3_prop'].mean())
# Out:
# 2281905.2384478673
# 0.5380225656393437
# 0.11595746965892631
# 0.34601996470172924

# %%
dataset_EU_JJA = dataset_EU[dataset_EU['month']>5]
dataset_EU_JJA = dataset_EU_JJA[dataset_EU_JJA['month']<9]
print(dataset_EU_JJA['pt1_prop'].mean())
print(dataset_EU_JJA['pt2_prop'].mean())
print(dataset_EU_JJA['pt3_prop'].mean())
# Out:
# 0.3202180035410475
# 0.08289696869505324
# 0.5968850277638996

# %%
dataset_EU_DJF = dataset_EU[dataset_EU['month']<3]
print(dataset_EU_DJF['pt1_prop'].mean())
print(dataset_EU_DJF['pt2_prop'].mean())
print(dataset_EU_DJF['pt3_prop'].mean())
# Out:
# 0.7499516147443306
# 0.1323547193225296
# 0.11769366593313976

# %%
print(dataset_AF['o3prod_mole_stacked'].mean())
print(dataset_AF['pt1_prop'].mean())
print(dataset_AF['pt2_prop'].mean())
print(dataset_AF['pt3_prop'].mean())
# Out:
# 7897021.3271315815
# 0.4410605362661569
# 0.16037547431420193
# 0.398563989419636

# %%
dataset_AF_JJA = dataset_AF[dataset_AF['month']>5]
dataset_AF_JJA = dataset_AF_JJA[dataset_AF_JJA['month']<9]
print(dataset_AF_JJA['pt1_prop'].mean())
print(dataset_AF_JJA['pt2_prop'].mean())
print(dataset_AF_JJA['pt3_prop'].mean())
# Out:
# 0.46329275654048446
# 0.17344701112983682
# 0.3632602323296785

# %%
dataset_AF_DJF = dataset_AF[dataset_AF['month']<3]
print(dataset_AF_DJF['pt1_prop'].mean())
print(dataset_AF_DJF['pt2_prop'].mean())
print(dataset_AF_DJF['pt3_prop'].mean())
# Out:
# 0.4400289892104779
# 0.14240160831620555
# 0.4175694024733167

# %%
print(dataset_AS['o3prod_mole_stacked'].mean())
print(dataset_AS['pt1_prop'].mean())
print(dataset_AS['pt2_prop'].mean())
print(dataset_AS['pt3_prop'].mean())
# Out:
# 4172310.634526653
# 0.39482351205258265
# 0.14725355829892184
# 0.4579229296484941

# %%
dataset_AS_JJA = dataset_AS[dataset_AS['month']>5]
dataset_AS_JJA = dataset_AS_JJA[dataset_AS_JJA['month']<9]
print(dataset_AS_JJA['pt1_prop'].mean())
print(dataset_AS_JJA['pt2_prop'].mean())
print(dataset_AS_JJA['pt3_prop'].mean())
# Out:
# 0.4641952845782021
# 0.17569767871294603
# 0.36010703670885225

# %%
dataset_AS_DJF = dataset_AS[dataset_AS['month']<3]
print(dataset_AS_DJF['pt1_prop'].mean())
print(dataset_AS_DJF['pt2_prop'].mean())
print(dataset_AS_DJF['pt3_prop'].mean())
# Out:
# 0.327358298194704
# 0.12795545262375668
# 0.5446862491815385

# %%
print(dataset_OC['o3prod_mole_stacked'].mean())
print(dataset_OC['pt1_prop'].mean())
print(dataset_OC['pt2_prop'].mean())
print(dataset_OC['pt3_prop'].mean())
# Out:
# 4000195.561420373
# 0.3941726104945208
# 0.15144903573970295
# 0.45437835376577473

# %%
dataset_OC_JJA = dataset_OC[dataset_OC['month']>5]
dataset_OC_JJA = dataset_OC_JJA[dataset_OC_JJA['month']<9]
print(dataset_OC_JJA['pt1_prop'].mean())
print(dataset_OC_JJA['pt2_prop'].mean())
print(dataset_OC_JJA['pt3_prop'].mean())
# Out:
# 0.4633146588969968
# 0.1802046597002755
# 0.3564806814027281

# %%
dataset_OC_DJF = dataset_OC[dataset_OC['month']<3]
print(dataset_OC_DJF['pt1_prop'].mean())
print(dataset_OC_DJF['pt2_prop'].mean())
print(dataset_OC_DJF['pt3_prop'].mean())
# Out:
# 0.3262552983335454
# 0.13149267225145092
# 0.5422520294150035

# %%
print(dataset_NA['o3loss_mole_stacked'].mean())
print(dataset_NA['pt4_prop'].mean())
print(dataset_NA['pt5_prop'].mean())
print(dataset_NA['pt6_prop'].mean())
print(dataset_NA['pt7_prop'].mean())
# Out:
# 368500.40772384143
# 0.4053645366092581
# 0.14434107219561793
# 0.3011043807155602
# 0.1491900104795637

# %%
print(dataset_NA_JJA['pt4_prop'].mean())
print(dataset_NA_JJA['pt5_prop'].mean())
print(dataset_NA_JJA['pt6_prop'].mean())
print(dataset_NA_JJA['pt7_prop'].mean())
# Out:
# 0.49330271570999806
# 0.0967421904066903
# 0.19349772875729868
# 0.21645736512601185

# %%
print(dataset_NA_DJF['pt4_prop'].mean())
print(dataset_NA_DJF['pt5_prop'].mean())
print(dataset_NA_DJF['pt6_prop'].mean())
print(dataset_NA_DJF['pt7_prop'].mean())
# Out:
# 0.36152424364951574
# 0.1678264718028125
# 0.36402021461612094
# 0.10662906993154844

# %%
print(dataset_SA['o3loss_mole_stacked'].mean())
print(dataset_SA['pt4_prop'].mean())
print(dataset_SA['pt5_prop'].mean())
print(dataset_SA['pt6_prop'].mean())
print(dataset_SA['pt7_prop'].mean())
# Out:
# 1561822.2248270216
# 0.5005552809407744
# 0.05362320507359354
# 0.03558676415641956
# 0.41023474982921326

# %%
print(dataset_SA_JJA['pt4_prop'].mean())
print(dataset_SA_JJA['pt5_prop'].mean())
print(dataset_SA_JJA['pt6_prop'].mean())
print(dataset_SA_JJA['pt7_prop'].mean())
# Out:
# 0.4524900166640991
# 0.07002837531302047
# 0.038908334683159386
# 0.43857327333972146

# %%
print(dataset_SA_DJF['pt4_prop'].mean())
print(dataset_SA_DJF['pt5_prop'].mean())
print(dataset_SA_DJF['pt6_prop'].mean())
print(dataset_SA_DJF['pt7_prop'].mean())
# Out:
# 0.5185538404620154
# 0.03585737145078074
# 0.027835620760109304
# 0.4177531673270931

# %%
print(dataset_EU['o3loss_mole_stacked'].mean())
print(dataset_EU['pt4_prop'].mean())
print(dataset_EU['pt5_prop'].mean())
print(dataset_EU['pt6_prop'].mean())
print(dataset_EU['pt7_prop'].mean())
# Out:
# 305650.74394854176
# 0.5120356640734985
# 0.18317044482969896
# 0.11074252666830825
# 0.1940513644284969

# %%
print(dataset_EU_JJA['pt4_prop'].mean())
print(dataset_EU_JJA['pt5_prop'].mean())
print(dataset_EU_JJA['pt6_prop'].mean())
print(dataset_EU_JJA['pt7_prop'].mean())
# Out:
# 0.5488602497952352
# 0.15424695450594653
# 0.08397482922250682
# 0.21291796647631211

# %%
print(dataset_EU_DJF['pt4_prop'].mean())
print(dataset_EU_DJF['pt5_prop'].mean())
print(dataset_EU_DJF['pt6_prop'].mean())
print(dataset_EU_DJF['pt7_prop'].mean())
# Out:
# 0.5552232398086193
# 0.1590080380735864
# 0.09167348589076368
# 0.1940952362270307

# %%
print(dataset_AF['o3loss_mole_stacked'].mean())
print(dataset_AF['pt4_prop'].mean())
print(dataset_AF['pt5_prop'].mean())
print(dataset_AF['pt6_prop'].mean())
print(dataset_AF['pt7_prop'].mean())
# Out:
# 1677538.0221601063
# 0.558933063651588
# 0.12967719318148072
# 0.15275666127960832
# 0.15863308188732272

# %%
print(dataset_AF_JJA['pt4_prop'].mean())
print(dataset_AF_JJA['pt5_prop'].mean())
print(dataset_AF_JJA['pt6_prop'].mean())
print(dataset_AF_JJA['pt7_prop'].mean())
# Out:
# 0.5981527796311971
# 0.13847267347448633
# 0.1410864786596881
# 0.12228806823463037

# %%
print(dataset_AF_DJF['pt4_prop'].mean())
print(dataset_AF_DJF['pt5_prop'].mean())
print(dataset_AF_DJF['pt6_prop'].mean())
print(dataset_AF_DJF['pt7_prop'].mean())
# Out:
# 0.5182852174315709
# 0.12869632465263423
# 0.16847194171773072
# 0.18454651619806425

# %%
print(dataset_AS['o3loss_mole_stacked'].mean())
print(dataset_AS['pt4_prop'].mean())
print(dataset_AS['pt5_prop'].mean())
print(dataset_AS['pt6_prop'].mean())
print(dataset_AS['pt7_prop'].mean())
# Out:
# 892336.0215819741
# 0.6205268439239022
# 0.11339403789599302
# 0.1476167825400947
# 0.11846233564001107

# %%
print(dataset_AS_JJA['pt4_prop'].mean())
print(dataset_AS_JJA['pt5_prop'].mean())
print(dataset_AS_JJA['pt6_prop'].mean())
print(dataset_AS_JJA['pt7_prop'].mean())
# Out:
# 0.5729577814471539
# 0.147135098972658
# 0.1896282588207418
# 0.09027886075944627

# %%
print(dataset_AS_DJF['pt4_prop'].mean())
print(dataset_AS_DJF['pt5_prop'].mean())
print(dataset_AS_DJF['pt6_prop'].mean())
print(dataset_AS_DJF['pt7_prop'].mean())
# Out:
# 0.6666167134851726
# 0.08235079124219968
# 0.11394257410986229
# 0.1370899211627646

# %%
print(dataset_OC['o3loss_mole_stacked'].mean())
print(dataset_OC['pt4_prop'].mean())
print(dataset_OC['pt5_prop'].mean())
print(dataset_OC['pt6_prop'].mean())
print(dataset_OC['pt7_prop'].mean())
# Out:
# 867318.0948919619
# 0.6209444042797938
# 0.11363810816591097
# 0.1465177218607057
# 0.11889976569358947

# %%
print(dataset_OC_JJA['pt4_prop'].mean())
print(dataset_OC_JJA['pt5_prop'].mean())
print(dataset_OC_JJA['pt6_prop'].mean())
print(dataset_OC_JJA['pt7_prop'].mean())
# Out:
# 0.568108945998808
# 0.14739421501013286
# 0.1884300021708342
# 0.09606683682022364

# %%
print(dataset_OC_DJF['pt4_prop'].mean())
print(dataset_OC_DJF['pt5_prop'].mean())
print(dataset_OC_DJF['pt6_prop'].mean())
print(dataset_OC_DJF['pt7_prop'].mean())
# Out:
# 0.6707945528269024
# 0.08222983737469756
# 0.11271550101804391
# 0.13426010878035502

# %%
dataset_land.to_csv('/Volumes/Database/Research/ozone-budget/UKESM1-0-LL_2010_2014_land(ver240113).csv', index=False)
